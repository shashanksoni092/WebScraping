# %%
import requests
import dataset
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
db = dataset.connect('sqlite:///quotes.db')
authors_seen = set()
base_url = 'http://quotes.toscrape.com/'
def clean_url(url):
    print("inside clean_url")
    # Clean '/author/Steve-Martin' to 'Steve-Martin'
    # Use urljoin to make an absolute URL
    url = urljoin(base_url, url)
    print(url)
    # Use urlparse to get out the path part
    path = urlparse(url).path
    print(path)
    # Now split the path by '/' and get the second part
    # E.g. '/author/Steve-Martin' -> ['', 'author', 'Steve-Martin']
    print(path.split('/')[2])
    return path.split('/')[2]
def scrape_quotes(html_soup):
    for quote in html_soup.select('div.quote'):
        quote_text = quote.find(class_='text').get_text(strip=True)
        quote_author_url = clean_url(quote.find(class_='author') \
                                     .find_next_sibling('a').get('href'))
        quote_tag_urls = [clean_url(a.get('href'))
                          for a in quote.find_all('a', class_='tag')]
        authors_seen.add(quote_author_url)
        # Store this quote and its tags
        quote_id = db['quotes'].insert({ 'text' : quote_text,
                                         'author' : quote_author_url })
        db['quote_tags'].insert_many(
                 [{'quote_id' : quote_id, 'tag_id' : tag} for tag in
                 quote_tag_urls])
def scrape_author(html_soup, author_id):

    author_name = html_soup.find(class_='author-title').get_text(strip=True)
    author_born_date = html_soup.find(class_='author-born-date').get_text(strip=True)
    author_born_loc = html_soup.find(class_='author-born-location').get_text(strip=True)
    author_desc = html_soup.find(class_='author-description').get_text(strip=True)
    db['authors'].insert({ 'author_id' : author_id,
                            'name' : author_name,
                            'born_date' : author_born_date,
                            'born_location' : author_born_loc,
                            'description' : author_desc})
# Start by scraping all the quote pages
url = base_url
while True:
    print('Now scraping page:', url)
    r = requests.get(url)
    html_soup = BeautifulSoup(r.text, 'html.parser')
    # Scrape the quotes
    scrape_quotes(html_soup)
    # Is there a next page?
    next_a = html_soup.select('li.next > a')
    if not next_a or not next_a[0].get('href'):
        break
    url = urljoin(url, next_a[0].get('href'))
    # Now fetch out the author information
for author_id in authors_seen:
    url = urljoin(base_url, '/author/' + author_id)
    print('Now scraping author:', url)
    r = requests.get(url)
    html_soup = BeautifulSoup(r.text, 'html.parser')
    # Scrape the author information
    scrape_author(html_soup, author_id)
# Out:
# Now scraping page: http://quotes.toscrape.com/
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/change/page/1/
# /tag/change/page/1/
# change
# inside clean_url
# http://quotes.toscrape.com/tag/deep-thoughts/page/1/
# /tag/deep-thoughts/page/1/
# deep-thoughts
# inside clean_url
# http://quotes.toscrape.com/tag/thinking/page/1/
# /tag/thinking/page/1/
# thinking
# inside clean_url
# http://quotes.toscrape.com/tag/world/page/1/
# /tag/world/page/1/
# world
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/abilities/page/1/
# /tag/abilities/page/1/
# abilities
# inside clean_url
# http://quotes.toscrape.com/tag/choices/page/1/
# /tag/choices/page/1/
# choices
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/live/page/1/
# /tag/live/page/1/
# live
# inside clean_url
# http://quotes.toscrape.com/tag/miracle/page/1/
# /tag/miracle/page/1/
# miracle
# inside clean_url
# http://quotes.toscrape.com/tag/miracles/page/1/
# /tag/miracles/page/1/
# miracles
# inside clean_url
# http://quotes.toscrape.com/author/Jane-Austen
# /author/Jane-Austen
# Jane-Austen
# inside clean_url
# http://quotes.toscrape.com/tag/aliteracy/page/1/
# /tag/aliteracy/page/1/
# aliteracy
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/classic/page/1/
# /tag/classic/page/1/
# classic
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/tag/be-yourself/page/1/
# /tag/be-yourself/page/1/
# be-yourself
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/adulthood/page/1/
# /tag/adulthood/page/1/
# adulthood
# inside clean_url
# http://quotes.toscrape.com/tag/success/page/1/
# /tag/success/page/1/
# success
# inside clean_url
# http://quotes.toscrape.com/tag/value/page/1/
# /tag/value/page/1/
# value
# inside clean_url
# http://quotes.toscrape.com/author/Andre-Gide
# /author/Andre-Gide
# Andre-Gide
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/Thomas-A-Edison
# /author/Thomas-A-Edison
# Thomas-A-Edison
# inside clean_url
# http://quotes.toscrape.com/tag/edison/page/1/
# /tag/edison/page/1/
# edison
# inside clean_url
# http://quotes.toscrape.com/tag/failure/page/1/
# /tag/failure/page/1/
# failure
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/paraphrased/page/1/
# /tag/paraphrased/page/1/
# paraphrased
# inside clean_url
# http://quotes.toscrape.com/author/Eleanor-Roosevelt
# /author/Eleanor-Roosevelt
# Eleanor-Roosevelt
# inside clean_url
# http://quotes.toscrape.com/tag/misattributed-eleanor-roosevelt/page/1/
# /tag/misattributed-eleanor-roosevelt/page/1/
# misattributed-eleanor-roosevelt
# inside clean_url
# http://quotes.toscrape.com/author/Steve-Martin
# /author/Steve-Martin
# Steve-Martin
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/obvious/page/1/
# /tag/obvious/page/1/
# obvious
# inside clean_url
# http://quotes.toscrape.com/tag/simile/page/1/
# /tag/simile/page/1/
# simile
# Now scraping page: http://quotes.toscrape.com/page/2/
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/tag/friends/page/1/
# /tag/friends/page/1/
# friends
# inside clean_url
# http://quotes.toscrape.com/tag/heartbreak/page/1/
# /tag/heartbreak/page/1/
# heartbreak
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/tag/sisters/page/1/
# /tag/sisters/page/1/
# sisters
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/courage/page/1/
# /tag/courage/page/1/
# courage
# inside clean_url
# http://quotes.toscrape.com/tag/friends/page/1/
# /tag/friends/page/1/
# friends
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/simplicity/page/1/
# /tag/simplicity/page/1/
# simplicity
# inside clean_url
# http://quotes.toscrape.com/tag/understand/page/1/
# /tag/understand/page/1/
# understand
# inside clean_url
# http://quotes.toscrape.com/author/Bob-Marley
# /author/Bob-Marley
# Bob-Marley
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/Dr-Seuss
# /author/Dr-Seuss
# Dr-Seuss
# inside clean_url
# http://quotes.toscrape.com/tag/fantasy/page/1/
# /tag/fantasy/page/1/
# fantasy
# inside clean_url
# http://quotes.toscrape.com/author/Douglas-Adams
# /author/Douglas-Adams
# Douglas-Adams
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/navigation/page/1/
# /tag/navigation/page/1/
# navigation
# inside clean_url
# http://quotes.toscrape.com/author/Elie-Wiesel
# /author/Elie-Wiesel
# Elie-Wiesel
# inside clean_url
# http://quotes.toscrape.com/tag/activism/page/1/
# /tag/activism/page/1/
# activism
# inside clean_url
# http://quotes.toscrape.com/tag/apathy/page/1/
# /tag/apathy/page/1/
# apathy
# inside clean_url
# http://quotes.toscrape.com/tag/hate/page/1/
# /tag/hate/page/1/
# hate
# inside clean_url
# http://quotes.toscrape.com/tag/indifference/page/1/
# /tag/indifference/page/1/
# indifference
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/tag/opposite/page/1/
# /tag/opposite/page/1/
# opposite
# inside clean_url
# http://quotes.toscrape.com/tag/philosophy/page/1/
# /tag/philosophy/page/1/
# philosophy
# inside clean_url
# http://quotes.toscrape.com/author/Friedrich-Nietzsche
# /author/Friedrich-Nietzsche
# Friedrich-Nietzsche
# inside clean_url
# http://quotes.toscrape.com/tag/friendship/page/1/
# /tag/friendship/page/1/
# friendship
# inside clean_url
# http://quotes.toscrape.com/tag/lack-of-friendship/page/1/
# /tag/lack-of-friendship/page/1/
# lack-of-friendship
# inside clean_url
# http://quotes.toscrape.com/tag/lack-of-love/page/1/
# /tag/lack-of-love/page/1/
# lack-of-love
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/tag/marriage/page/1/
# /tag/marriage/page/1/
# marriage
# inside clean_url
# http://quotes.toscrape.com/tag/unhappy-marriage/page/1/
# /tag/unhappy-marriage/page/1/
# unhappy-marriage
# inside clean_url
# http://quotes.toscrape.com/author/Mark-Twain
# /author/Mark-Twain
# Mark-Twain
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/contentment/page/1/
# /tag/contentment/page/1/
# contentment
# inside clean_url
# http://quotes.toscrape.com/tag/friends/page/1/
# /tag/friends/page/1/
# friends
# inside clean_url
# http://quotes.toscrape.com/tag/friendship/page/1/
# /tag/friendship/page/1/
# friendship
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/author/Allen-Saunders
# /author/Allen-Saunders
# Allen-Saunders
# inside clean_url
# http://quotes.toscrape.com/tag/fate/page/1/
# /tag/fate/page/1/
# fate
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/misattributed-john-lennon/page/1/
# /tag/misattributed-john-lennon/page/1/
# misattributed-john-lennon
# inside clean_url
# http://quotes.toscrape.com/tag/planning/page/1/
# /tag/planning/page/1/
# planning
# inside clean_url
# http://quotes.toscrape.com/tag/plans/page/1/
# /tag/plans/page/1/
# plans
# Now scraping page: http://quotes.toscrape.com/page/3/
# inside clean_url
# http://quotes.toscrape.com/author/Pablo-Neruda
# /author/Pablo-Neruda
# Pablo-Neruda
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/tag/poetry/page/1/
# /tag/poetry/page/1/
# poetry
# inside clean_url
# http://quotes.toscrape.com/author/Ralph-Waldo-Emerson
# /author/Ralph-Waldo-Emerson
# Ralph-Waldo-Emerson
# inside clean_url
# http://quotes.toscrape.com/tag/happiness/page/1/
# /tag/happiness/page/1/
# happiness
# inside clean_url
# http://quotes.toscrape.com/author/Mother-Teresa
# /author/Mother-Teresa
# Mother-Teresa
# inside clean_url
# http://quotes.toscrape.com/tag/attributed-no-source/page/1/
# /tag/attributed-no-source/page/1/
# attributed-no-source
# inside clean_url
# http://quotes.toscrape.com/author/Garrison-Keillor
# /author/Garrison-Keillor
# Garrison-Keillor
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/religion/page/1/
# /tag/religion/page/1/
# religion
# inside clean_url
# http://quotes.toscrape.com/author/Jim-Henson
# /author/Jim-Henson
# Jim-Henson
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/author/Dr-Seuss
# /author/Dr-Seuss
# Dr-Seuss
# inside clean_url
# http://quotes.toscrape.com/tag/comedy/page/1/
# /tag/comedy/page/1/
# comedy
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/yourself/page/1/
# /tag/yourself/page/1/
# yourself
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/children/page/1/
# /tag/children/page/1/
# children
# inside clean_url
# http://quotes.toscrape.com/tag/fairy-tales/page/1/
# /tag/fairy-tales/page/1/
# fairy-tales
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/imagination/page/1/
# /tag/imagination/page/1/
# imagination
# inside clean_url
# http://quotes.toscrape.com/author/Bob-Marley
# /author/Bob-Marley
# Bob-Marley
# inside clean_url
# http://quotes.toscrape.com/tag/music/page/1/
# /tag/music/page/1/
# music
# Now scraping page: http://quotes.toscrape.com/page/4/
# inside clean_url
# http://quotes.toscrape.com/author/Dr-Seuss
# /author/Dr-Seuss
# Dr-Seuss
# inside clean_url
# http://quotes.toscrape.com/tag/learning/page/1/
# /tag/learning/page/1/
# learning
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# inside clean_url
# http://quotes.toscrape.com/tag/seuss/page/1/
# /tag/seuss/page/1/
# seuss
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/dumbledore/page/1/
# /tag/dumbledore/page/1/
# dumbledore
# inside clean_url
# http://quotes.toscrape.com/author/Bob-Marley
# /author/Bob-Marley
# Bob-Marley
# inside clean_url
# http://quotes.toscrape.com/tag/friendship/page/1/
# /tag/friendship/page/1/
# friendship
# inside clean_url
# http://quotes.toscrape.com/author/Mother-Teresa
# /author/Mother-Teresa
# Mother-Teresa
# inside clean_url
# http://quotes.toscrape.com/tag/misattributed-to-mother-teresa/page/1/
# /tag/misattributed-to-mother-teresa/page/1/
# misattributed-to-mother-teresa
# inside clean_url
# http://quotes.toscrape.com/tag/paraphrased/page/1/
# /tag/paraphrased/page/1/
# paraphrased
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/death/page/1/
# /tag/death/page/1/
# death
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/author/Charles-M-Schulz
# /author/Charles-M-Schulz
# Charles-M-Schulz
# inside clean_url
# http://quotes.toscrape.com/tag/chocolate/page/1/
# /tag/chocolate/page/1/
# chocolate
# inside clean_url
# http://quotes.toscrape.com/tag/food/page/1/
# /tag/food/page/1/
# food
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/author/William-Nicholson
# /author/William-Nicholson
# William-Nicholson
# inside clean_url
# http://quotes.toscrape.com/tag/misattributed-to-c-s-lewis/page/1/
# /tag/misattributed-to-c-s-lewis/page/1/
# misattributed-to-c-s-lewis
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/knowledge/page/1/
# /tag/knowledge/page/1/
# knowledge
# inside clean_url
# http://quotes.toscrape.com/tag/learning/page/1/
# /tag/learning/page/1/
# learning
# inside clean_url
# http://quotes.toscrape.com/tag/understanding/page/1/
# /tag/understanding/page/1/
# understanding
# inside clean_url
# http://quotes.toscrape.com/tag/wisdom/page/1/
# /tag/wisdom/page/1/
# wisdom
# inside clean_url
# http://quotes.toscrape.com/author/Jorge-Luis-Borges
# /author/Jorge-Luis-Borges
# Jorge-Luis-Borges
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/library/page/1/
# /tag/library/page/1/
# library
# inside clean_url
# http://quotes.toscrape.com/author/George-Eliot
# /author/George-Eliot
# George-Eliot
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# Now scraping page: http://quotes.toscrape.com/page/5/
# inside clean_url
# http://quotes.toscrape.com/author/George-R-R-Martin
# /author/George-R-R-Martin
# George-R-R-Martin
# inside clean_url
# http://quotes.toscrape.com/tag/read/page/1/
# /tag/read/page/1/
# read
# inside clean_url
# http://quotes.toscrape.com/tag/readers/page/1/
# /tag/readers/page/1/
# readers
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# inside clean_url
# http://quotes.toscrape.com/tag/reading-books/page/1/
# /tag/reading-books/page/1/
# reading-books
# inside clean_url
# http://quotes.toscrape.com/author/C-S-Lewis
# /author/C-S-Lewis
# C-S-Lewis
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# inside clean_url
# http://quotes.toscrape.com/tag/tea/page/1/
# /tag/tea/page/1/
# tea
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/tag/girls/page/1/
# /tag/girls/page/1/
# girls
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/simile/page/1/
# /tag/simile/page/1/
# simile
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/tag/attributed-no-source/page/1/
# /tag/attributed-no-source/page/1/
# attributed-no-source
# inside clean_url
# http://quotes.toscrape.com/author/Martin-Luther-King-Jr
# /author/Martin-Luther-King-Jr
# Martin-Luther-King-Jr
# inside clean_url
# http://quotes.toscrape.com/tag/hope/page/1/
# /tag/hope/page/1/
# hope
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/dumbledore/page/1/
# /tag/dumbledore/page/1/
# dumbledore
# inside clean_url
# http://quotes.toscrape.com/author/James-Baldwin
# /author/James-Baldwin
# James-Baldwin
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# Now scraping page: http://quotes.toscrape.com/page/6/
# inside clean_url
# http://quotes.toscrape.com/author/Jane-Austen
# /author/Jane-Austen
# Jane-Austen
# inside clean_url
# http://quotes.toscrape.com/tag/friendship/page/1/
# /tag/friendship/page/1/
# friendship
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/Eleanor-Roosevelt
# /author/Eleanor-Roosevelt
# Eleanor-Roosevelt
# inside clean_url
# http://quotes.toscrape.com/tag/attributed/page/1/
# /tag/attributed/page/1/
# attributed
# inside clean_url
# http://quotes.toscrape.com/tag/fear/page/1/
# /tag/fear/page/1/
# fear
# inside clean_url
# http://quotes.toscrape.com/tag/inspiration/page/1/
# /tag/inspiration/page/1/
# inspiration
# inside clean_url
# http://quotes.toscrape.com/author/Marilyn-Monroe
# /author/Marilyn-Monroe
# Marilyn-Monroe
# inside clean_url
# http://quotes.toscrape.com/tag/attributed-no-source/page/1/
# /tag/attributed-no-source/page/1/
# attributed-no-source
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/music/page/1/
# /tag/music/page/1/
# music
# inside clean_url
# http://quotes.toscrape.com/author/Haruki-Murakami
# /author/Haruki-Murakami
# Haruki-Murakami
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/thought/page/1/
# /tag/thought/page/1/
# thought
# inside clean_url
# http://quotes.toscrape.com/author/Alexandre-Dumas-fils
# /author/Alexandre-Dumas-fils
# Alexandre-Dumas-fils
# inside clean_url
# http://quotes.toscrape.com/tag/misattributed-to-einstein/page/1/
# /tag/misattributed-to-einstein/page/1/
# misattributed-to-einstein
# inside clean_url
# http://quotes.toscrape.com/author/Stephenie-Meyer
# /author/Stephenie-Meyer
# Stephenie-Meyer
# inside clean_url
# http://quotes.toscrape.com/tag/drug/page/1/
# /tag/drug/page/1/
# drug
# inside clean_url
# http://quotes.toscrape.com/tag/romance/page/1/
# /tag/romance/page/1/
# romance
# inside clean_url
# http://quotes.toscrape.com/tag/simile/page/1/
# /tag/simile/page/1/
# simile
# inside clean_url
# http://quotes.toscrape.com/author/Ernest-Hemingway
# /author/Ernest-Hemingway
# Ernest-Hemingway
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/friends/page/1/
# /tag/friends/page/1/
# friends
# inside clean_url
# http://quotes.toscrape.com/tag/novelist-quotes/page/1/
# /tag/novelist-quotes/page/1/
# novelist-quotes
# inside clean_url
# http://quotes.toscrape.com/author/Helen-Keller
# /author/Helen-Keller
# Helen-Keller
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/author/George-Bernard-Shaw
# /author/George-Bernard-Shaw
# George-Bernard-Shaw
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/yourself/page/1/
# /tag/yourself/page/1/
# yourself
# Now scraping page: http://quotes.toscrape.com/page/7/
# inside clean_url
# http://quotes.toscrape.com/author/Charles-Bukowski
# /author/Charles-Bukowski
# Charles-Bukowski
# inside clean_url
# http://quotes.toscrape.com/tag/alcohol/page/1/
# /tag/alcohol/page/1/
# alcohol
# inside clean_url
# http://quotes.toscrape.com/author/Suzanne-Collins
# /author/Suzanne-Collins
# Suzanne-Collins
# inside clean_url
# http://quotes.toscrape.com/tag/the-hunger-games/page/1/
# /tag/the-hunger-games/page/1/
# the-hunger-games
# inside clean_url
# http://quotes.toscrape.com/author/Suzanne-Collins
# /author/Suzanne-Collins
# Suzanne-Collins
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/author/C-S-Lewis
# /author/C-S-Lewis
# C-S-Lewis
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/J-R-R-Tolkien
# /author/J-R-R-Tolkien
# J-R-R-Tolkien
# inside clean_url
# http://quotes.toscrape.com/tag/bilbo/page/1/
# /tag/bilbo/page/1/
# bilbo
# inside clean_url
# http://quotes.toscrape.com/tag/journey/page/1/
# /tag/journey/page/1/
# journey
# inside clean_url
# http://quotes.toscrape.com/tag/lost/page/1/
# /tag/lost/page/1/
# lost
# inside clean_url
# http://quotes.toscrape.com/tag/quest/page/1/
# /tag/quest/page/1/
# quest
# inside clean_url
# http://quotes.toscrape.com/tag/travel/page/1/
# /tag/travel/page/1/
# travel
# inside clean_url
# http://quotes.toscrape.com/tag/wander/page/1/
# /tag/wander/page/1/
# wander
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/live-death-love/page/1/
# /tag/live-death-love/page/1/
# live-death-love
# inside clean_url
# http://quotes.toscrape.com/author/Ernest-Hemingway
# /author/Ernest-Hemingway
# Ernest-Hemingway
# inside clean_url
# http://quotes.toscrape.com/tag/good/page/1/
# /tag/good/page/1/
# good
# inside clean_url
# http://quotes.toscrape.com/tag/writing/page/1/
# /tag/writing/page/1/
# writing
# inside clean_url
# http://quotes.toscrape.com/author/Ralph-Waldo-Emerson
# /author/Ralph-Waldo-Emerson
# Ralph-Waldo-Emerson
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/tag/regrets/page/1/
# /tag/regrets/page/1/
# regrets
# inside clean_url
# http://quotes.toscrape.com/author/Mark-Twain
# /author/Mark-Twain
# Mark-Twain
# inside clean_url
# http://quotes.toscrape.com/tag/education/page/1/
# /tag/education/page/1/
# education
# inside clean_url
# http://quotes.toscrape.com/author/Dr-Seuss
# /author/Dr-Seuss
# Dr-Seuss
# inside clean_url
# http://quotes.toscrape.com/tag/troubles/page/1/
# /tag/troubles/page/1/
# troubles
# Now scraping page: http://quotes.toscrape.com/page/8/
# inside clean_url
# http://quotes.toscrape.com/author/Alfred-Tennyson
# /author/Alfred-Tennyson
# Alfred-Tennyson
# inside clean_url
# http://quotes.toscrape.com/tag/friendship/page/1/
# /tag/friendship/page/1/
# friendship
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/Charles-Bukowski
# /author/Charles-Bukowski
# Charles-Bukowski
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/author/Terry-Pratchett
# /author/Terry-Pratchett
# Terry-Pratchett
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/open-mind/page/1/
# /tag/open-mind/page/1/
# open-mind
# inside clean_url
# http://quotes.toscrape.com/tag/thinking/page/1/
# /tag/thinking/page/1/
# thinking
# inside clean_url
# http://quotes.toscrape.com/author/Dr-Seuss
# /author/Dr-Seuss
# Dr-Seuss
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/philosophy/page/1/
# /tag/philosophy/page/1/
# philosophy
# inside clean_url
# http://quotes.toscrape.com/author/J-D-Salinger
# /author/J-D-Salinger
# J-D-Salinger
# inside clean_url
# http://quotes.toscrape.com/tag/authors/page/1/
# /tag/authors/page/1/
# authors
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/literature/page/1/
# /tag/literature/page/1/
# literature
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# inside clean_url
# http://quotes.toscrape.com/tag/writing/page/1/
# /tag/writing/page/1/
# writing
# inside clean_url
# http://quotes.toscrape.com/author/George-Carlin
# /author/George-Carlin
# George-Carlin
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/insanity/page/1/
# /tag/insanity/page/1/
# insanity
# inside clean_url
# http://quotes.toscrape.com/tag/lies/page/1/
# /tag/lies/page/1/
# lies
# inside clean_url
# http://quotes.toscrape.com/tag/lying/page/1/
# /tag/lying/page/1/
# lying
# inside clean_url
# http://quotes.toscrape.com/tag/self-indulgence/page/1/
# /tag/self-indulgence/page/1/
# self-indulgence
# inside clean_url
# http://quotes.toscrape.com/tag/truth/page/1/
# /tag/truth/page/1/
# truth
# inside clean_url
# http://quotes.toscrape.com/author/John-Lennon
# /author/John-Lennon
# John-Lennon
# inside clean_url
# http://quotes.toscrape.com/tag/beatles/page/1/
# /tag/beatles/page/1/
# beatles
# inside clean_url
# http://quotes.toscrape.com/tag/connection/page/1/
# /tag/connection/page/1/
# connection
# inside clean_url
# http://quotes.toscrape.com/tag/dreamers/page/1/
# /tag/dreamers/page/1/
# dreamers
# inside clean_url
# http://quotes.toscrape.com/tag/dreaming/page/1/
# /tag/dreaming/page/1/
# dreaming
# inside clean_url
# http://quotes.toscrape.com/tag/dreams/page/1/
# /tag/dreams/page/1/
# dreams
# inside clean_url
# http://quotes.toscrape.com/tag/hope/page/1/
# /tag/hope/page/1/
# hope
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/tag/peace/page/1/
# /tag/peace/page/1/
# peace
# inside clean_url
# http://quotes.toscrape.com/author/W-C-Fields
# /author/W-C-Fields
# W-C-Fields
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/sinister/page/1/
# /tag/sinister/page/1/
# sinister
# inside clean_url
# http://quotes.toscrape.com/author/Ayn-Rand
# /author/Ayn-Rand
# Ayn-Rand
# inside clean_url
# http://quotes.toscrape.com/author/Mark-Twain
# /author/Mark-Twain
# Mark-Twain
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/classic/page/1/
# /tag/classic/page/1/
# classic
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# Now scraping page: http://quotes.toscrape.com/page/9/
# inside clean_url
# http://quotes.toscrape.com/author/Albert-Einstein
# /author/Albert-Einstein
# Albert-Einstein
# inside clean_url
# http://quotes.toscrape.com/tag/mistakes/page/1/
# /tag/mistakes/page/1/
# mistakes
# inside clean_url
# http://quotes.toscrape.com/author/Jane-Austen
# /author/Jane-Austen
# Jane-Austen
# inside clean_url
# http://quotes.toscrape.com/tag/humor/page/1/
# /tag/humor/page/1/
# humor
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/tag/romantic/page/1/
# /tag/romantic/page/1/
# romantic
# inside clean_url
# http://quotes.toscrape.com/tag/women/page/1/
# /tag/women/page/1/
# women
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/integrity/page/1/
# /tag/integrity/page/1/
# integrity
# inside clean_url
# http://quotes.toscrape.com/author/Jane-Austen
# /author/Jane-Austen
# Jane-Austen
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/library/page/1/
# /tag/library/page/1/
# library
# inside clean_url
# http://quotes.toscrape.com/tag/reading/page/1/
# /tag/reading/page/1/
# reading
# inside clean_url
# http://quotes.toscrape.com/author/Jane-Austen
# /author/Jane-Austen
# Jane-Austen
# inside clean_url
# http://quotes.toscrape.com/tag/elizabeth-bennet/page/1/
# /tag/elizabeth-bennet/page/1/
# elizabeth-bennet
# inside clean_url
# http://quotes.toscrape.com/tag/jane-austen/page/1/
# /tag/jane-austen/page/1/
# jane-austen
# inside clean_url
# http://quotes.toscrape.com/author/C-S-Lewis
# /author/C-S-Lewis
# C-S-Lewis
# inside clean_url
# http://quotes.toscrape.com/tag/age/page/1/
# /tag/age/page/1/
# age
# inside clean_url
# http://quotes.toscrape.com/tag/fairytales/page/1/
# /tag/fairytales/page/1/
# fairytales
# inside clean_url
# http://quotes.toscrape.com/tag/growing-up/page/1/
# /tag/growing-up/page/1/
# growing-up
# inside clean_url
# http://quotes.toscrape.com/author/C-S-Lewis
# /author/C-S-Lewis
# C-S-Lewis
# inside clean_url
# http://quotes.toscrape.com/tag/god/page/1/
# /tag/god/page/1/
# god
# inside clean_url
# http://quotes.toscrape.com/author/Mark-Twain
# /author/Mark-Twain
# Mark-Twain
# inside clean_url
# http://quotes.toscrape.com/tag/death/page/1/
# /tag/death/page/1/
# death
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/author/Mark-Twain
# /author/Mark-Twain
# Mark-Twain
# inside clean_url
# http://quotes.toscrape.com/tag/misattributed-mark-twain/page/1/
# /tag/misattributed-mark-twain/page/1/
# misattributed-mark-twain
# inside clean_url
# http://quotes.toscrape.com/tag/truth/page/1/
# /tag/truth/page/1/
# truth
# inside clean_url
# http://quotes.toscrape.com/author/C-S-Lewis
# /author/C-S-Lewis
# C-S-Lewis
# inside clean_url
# http://quotes.toscrape.com/tag/christianity/page/1/
# /tag/christianity/page/1/
# christianity
# inside clean_url
# http://quotes.toscrape.com/tag/faith/page/1/
# /tag/faith/page/1/
# faith
# inside clean_url
# http://quotes.toscrape.com/tag/religion/page/1/
# /tag/religion/page/1/
# religion
# inside clean_url
# http://quotes.toscrape.com/tag/sun/page/1/
# /tag/sun/page/1/
# sun
# Now scraping page: http://quotes.toscrape.com/page/10/
# inside clean_url
# http://quotes.toscrape.com/author/J-K-Rowling
# /author/J-K-Rowling
# J-K-Rowling
# inside clean_url
# http://quotes.toscrape.com/tag/truth/page/1/
# /tag/truth/page/1/
# truth
# inside clean_url
# http://quotes.toscrape.com/author/Jimi-Hendrix
# /author/Jimi-Hendrix
# Jimi-Hendrix
# inside clean_url
# http://quotes.toscrape.com/tag/death/page/1/
# /tag/death/page/1/
# death
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/author/J-M-Barrie
# /author/J-M-Barrie
# J-M-Barrie
# inside clean_url
# http://quotes.toscrape.com/tag/adventure/page/1/
# /tag/adventure/page/1/
# adventure
# inside clean_url
# http://quotes.toscrape.com/tag/love/page/1/
# /tag/love/page/1/
# love
# inside clean_url
# http://quotes.toscrape.com/author/E-E-Cummings
# /author/E-E-Cummings
# E-E-Cummings
# inside clean_url
# http://quotes.toscrape.com/tag/courage/page/1/
# /tag/courage/page/1/
# courage
# inside clean_url
# http://quotes.toscrape.com/author/Khaled-Hosseini
# /author/Khaled-Hosseini
# Khaled-Hosseini
# inside clean_url
# http://quotes.toscrape.com/tag/life/page/1/
# /tag/life/page/1/
# life
# inside clean_url
# http://quotes.toscrape.com/author/Harper-Lee
# /author/Harper-Lee
# Harper-Lee
# inside clean_url
# http://quotes.toscrape.com/tag/better-life-empathy/page/1/
# /tag/better-life-empathy/page/1/
# better-life-empathy
# inside clean_url
# http://quotes.toscrape.com/author/Madeleine-LEngle
# /author/Madeleine-LEngle
# Madeleine-LEngle
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/children/page/1/
# /tag/children/page/1/
# children
# inside clean_url
# http://quotes.toscrape.com/tag/difficult/page/1/
# /tag/difficult/page/1/
# difficult
# inside clean_url
# http://quotes.toscrape.com/tag/grown-ups/page/1/
# /tag/grown-ups/page/1/
# grown-ups
# inside clean_url
# http://quotes.toscrape.com/tag/write/page/1/
# /tag/write/page/1/
# write
# inside clean_url
# http://quotes.toscrape.com/tag/writers/page/1/
# /tag/writers/page/1/
# writers
# inside clean_url
# http://quotes.toscrape.com/tag/writing/page/1/
# /tag/writing/page/1/
# writing
# inside clean_url
# http://quotes.toscrape.com/author/Mark-Twain
# /author/Mark-Twain
# Mark-Twain
# inside clean_url
# http://quotes.toscrape.com/tag/truth/page/1/
# /tag/truth/page/1/
# truth
# inside clean_url
# http://quotes.toscrape.com/author/Dr-Seuss
# /author/Dr-Seuss
# Dr-Seuss
# inside clean_url
# http://quotes.toscrape.com/tag/inspirational/page/1/
# /tag/inspirational/page/1/
# inspirational
# inside clean_url
# http://quotes.toscrape.com/author/George-R-R-Martin
# /author/George-R-R-Martin
# George-R-R-Martin
# inside clean_url
# http://quotes.toscrape.com/tag/books/page/1/
# /tag/books/page/1/
# books
# inside clean_url
# http://quotes.toscrape.com/tag/mind/page/1/
# /tag/mind/page/1/
# mind
# Now scraping author: http://quotes.toscrape.com/author/Jim-Henson
# Now scraping author: http://quotes.toscrape.com/author/George-Eliot
# Now scraping author: http://quotes.toscrape.com/author/Alexandre-Dumas-fils
# Now scraping author: http://quotes.toscrape.com/author/George-Carlin
# Now scraping author: http://quotes.toscrape.com/author/Marilyn-Monroe
# Now scraping author: http://quotes.toscrape.com/author/C-S-Lewis
# Now scraping author: http://quotes.toscrape.com/author/Alfred-Tennyson
# Now scraping author: http://quotes.toscrape.com/author/Garrison-Keillor
# Now scraping author: http://quotes.toscrape.com/author/Thomas-A-Edison
# Now scraping author: http://quotes.toscrape.com/author/John-Lennon
# Now scraping author: http://quotes.toscrape.com/author/W-C-Fields
# Now scraping author: http://quotes.toscrape.com/author/Charles-M-Schulz
# Now scraping author: http://quotes.toscrape.com/author/William-Nicholson
# Now scraping author: http://quotes.toscrape.com/author/Stephenie-Meyer
# Now scraping author: http://quotes.toscrape.com/author/Haruki-Murakami
# Now scraping author: http://quotes.toscrape.com/author/Martin-Luther-King-Jr
# Now scraping author: http://quotes.toscrape.com/author/Terry-Pratchett
# Now scraping author: http://quotes.toscrape.com/author/E-E-Cummings
# Now scraping author: http://quotes.toscrape.com/author/Steve-Martin
# Now scraping author: http://quotes.toscrape.com/author/Dr-Seuss
# Now scraping author: http://quotes.toscrape.com/author/Douglas-Adams
# Now scraping author: http://quotes.toscrape.com/author/Helen-Keller
# Now scraping author: http://quotes.toscrape.com/author/Mark-Twain
# Now scraping author: http://quotes.toscrape.com/author/J-K-Rowling
# Now scraping author: http://quotes.toscrape.com/author/Jane-Austen
# Now scraping author: http://quotes.toscrape.com/author/Charles-Bukowski
# Now scraping author: http://quotes.toscrape.com/author/J-R-R-Tolkien
# Now scraping author: http://quotes.toscrape.com/author/J-M-Barrie
# Now scraping author: http://quotes.toscrape.com/author/Bob-Marley
# Now scraping author: http://quotes.toscrape.com/author/Eleanor-Roosevelt
# Now scraping author: http://quotes.toscrape.com/author/Pablo-Neruda
# Now scraping author: http://quotes.toscrape.com/author/Khaled-Hosseini
# Now scraping author: http://quotes.toscrape.com/author/Suzanne-Collins
# Now scraping author: http://quotes.toscrape.com/author/Albert-Einstein
# Now scraping author: http://quotes.toscrape.com/author/Ernest-Hemingway
# Now scraping author: http://quotes.toscrape.com/author/Ayn-Rand
# Now scraping author: http://quotes.toscrape.com/author/James-Baldwin
# Now scraping author: http://quotes.toscrape.com/author/J-D-Salinger
# Now scraping author: http://quotes.toscrape.com/author/Madeleine-LEngle
# Now scraping author: http://quotes.toscrape.com/author/Friedrich-Nietzsche
# Now scraping author: http://quotes.toscrape.com/author/Elie-Wiesel
# Now scraping author: http://quotes.toscrape.com/author/Andre-Gide
# Now scraping author: http://quotes.toscrape.com/author/Allen-Saunders
# Now scraping author: http://quotes.toscrape.com/author/Mother-Teresa
# Now scraping author: http://quotes.toscrape.com/author/George-R-R-Martin
# Now scraping author: http://quotes.toscrape.com/author/Harper-Lee
# Now scraping author: http://quotes.toscrape.com/author/Jorge-Luis-Borges
# Now scraping author: http://quotes.toscrape.com/author/George-Bernard-Shaw
# Now scraping author: http://quotes.toscrape.com/author/Ralph-Waldo-Emerson
# Now scraping author: http://quotes.toscrape.com/author/Jimi-Hendrix
