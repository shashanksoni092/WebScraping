# %%
import urllib
from bs4 import BeautifulSoup

test_url=urllib.request.urlopen("http://rnsit.ac.in/ise.html")
html=test_url.read()
test_url.close()

# %%
soup=BeautifulSoup(html)    
soup
# Out:
# /home/shashanksoni092/dsnew/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/shashanksoni092/dsnew/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <!DOCTYPE html>
# <html>
# <head><style>
#     .right_icons {
#         float: right !important;
#     }
#
#     .listss {
#         padding-left: 10px;
#     }
# </style>
# <title>Computer Science and Engineering</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link alt="logo" href="images/logo.png" rel="icon" type="image/png"/>
# <link href="manifest.json" rel="manifest"/>
# <meta content="#021B38" name="theme-color"/>
# <meta content="app-id=myAppStoreID, app-argument=myURL" name="RNSIT"/>
# <link href="imgages/logo.png" rel="apple-touch-icon"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="RNSIT" name="RNSIT"/>
# <link href="images/logo.png" rel="icon" sizes="192x192"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Bree+Serif" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Sansita:400,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lobster" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Mada" rel="stylesheet"/>
# <link href="css/dept.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.98.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="css/footer.css" rel="stylesheet" type="text/css"/>
# <link href="css/modal.css" rel="stylesheet" type="text/css"/>
# <link href="css/nav.css" rel="stylesheet" type="text/css"/>
# <link href="css/modal.css" rel="stylesheet" type="text/css"/>
# <link href="images/logo.png" rel="icon" type="image/png"/>
# <script src="https://code.jquery.com/jquery-2.1.1.min.js" type="text/javascript"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.98.1/js/materialize.min.js"></script>
# </head><body>
# <nav class="nav navin">
# <div class="nav-wrapper">
# <img alt="rnsit logo" class="svg-logo hidden" src="images/RNSIT.svg" style="height: 65px; width: 65px;"/>
# <a class="brand-logo" href="index.html" style="color: white; margin-left:0px; ">RNSIT</a>
# <a class="button-collapse" data-activates="mobile-demo" href="#"><i class="material-icons">menu</i></a>
# <ul class="right hide-on-med-and-down" id="nav-mobile">
# <!-- <li class ="navali"><a id="home" href="index.html">Home</a></li> -->
# <li class="navali"><a class="dropdown-button" data-activates="dropdown3" href="#!">About Us<i class="material-icons right">arrow_drop_down</i></a></li>
# <li class="navali"><a href="contact.html" id="contact" onclick="navig('contact');">Contact</a></li>
# <!-- Dropdown Trigger -->
# <li class="navali"><a class="dropdown-button" data-activates="dropdown1" href="#!">Departments<i class="material-icons right">arrow_drop_down</i></a></li>
# <li class="navali"><a class="dropdown-button" data-activates="dropdown2" href="#!">More<i class="material-icons right">arrow_drop_down</i></a></li>
# <!-- Dropdown Structure -->
# <ul class="dropdown-content" id="dropdown1">
# <li class="navali"><a href="cse.html" id="cse">CSE</a></li>
# <li class="navali"><a href="ece.html" id="ece">ECE</a></li>
# <li class="navali"><a href="eee.html" id="eee">EEE</a></li>
# <li class="navali"><a href="ise.html" id="ise">ISE</a></li>
# <li class="navali"><a href="eie.html" id="eie">IT / EIE</a></li>
# <li class="navali"><a href="mech.html" id="mech">MECH</a></li>
# <li class="navali"><a href="civil.html" id="civil">CIVIL</a></li>
# <li class="divider"></li>
# <li class="navali"><a href="http://www.rnsitmba.ac.in/" id="mba">MBA</a></li>
# <li class="navali"><a href="mca.html" id="mca">MCA</a></li>
# <li class="divider"></li>
# <li class="navali"><a href="physics.html" id="physics">Physics</a></li>
# <li class="navali"><a href="chemistry.html" id="chemistry">Chemistry</a></li>
# <li class="navali"><a href="mathematics.html" id="mathematics">Mathematics</a></li>
# <li class="divider"></li>
# <li class="navali"><a href="hr.html" id="eee">Placements &amp; HR</a></li>
# </ul>
# </ul>
# <ul class="dropdown-content" id="dropdown2">
# <li class="navali"><a href="alumni.html" id="cse">ALUMNI</a></li>
# <li class="navali"><a href="admissions.html" id="ece">ADMISSIONS &amp; OFFICE</a></li>
# <li class="navali"><a href="cultural.html" id="mca">CULTURAL</a></li>
# <li class="navali"><a href="facilities.html" id="mca">FACILITIES</a></li>
# </ul>
# <ul class="dropdown-content" id="dropdown3">
# <li class="navali"><a href="chairman.html" id="chair">CHAIRMAN</a></li>
# <li class="navali"><a href="director.html" id="diret">DIRECTOR</a></li>
# <li class="navali"><a href="principal.html" id="princi">PRINCIPAL</a></li>
# <li class="navali"><a href="registrar.html" id="regi">REGISTRAR</a></li>
# </ul>
# <!--mobile!-->
# <ul class="side-nav" id="mobile-demo">
# <li class="navali"><a href="index.html" id="home">Home</a></li>
# <li class="navali"><a class="dropNav2">About Us<i class="material-icons right aud">arrow_drop_down</i></a></li>
# <li class="innerli">
# <div class="innerNav2">
# <a class="nava" href="chairman.html" id="chair">Chairman</a>
# <a class="nava" href="director.html" id="direct">Director</a>
# <a class="nava" href="principal.html" id="princi">Principal</a>
# <a class="nava" href="registrar.html" id="regi">Registrar</a>
# </div>
# </li>
# <li class="navali"><a href="contact.html" id="contact">Contact</a></li>
# <li class="navali"><a class="dropNav">Departments<i class="material-icons right dd">arrow_drop_down</i></a></li>
# <li class="innerli">
# <div class="innerNav">
# <ul class="navali">
# <li class=" nava divider"></li>
# </ul>
# <a class="nava" href="cse.html" id="cse">CSE</a>
# <a class="nava" href="ece.html" id="ece">ECE</a>
# <a class="nava" href="eee.html" id="eee">EEE</a>
# <a class="nava" href="ise.html" id="ise">ISE</a>
# <a class="nava" href="eie.html" id="eie">IT / EIE</a>
# <a class="nava" href="mech.html" id="mech">MECH</a>
# <a class="nava" href="civil.html" id="civil">CIVIL</a>
# <ul class="navali">
# <li class=" nava divider" id=""></li>
# </ul>
# <a class="nava awes" href="http://www.rnsitmba.ac.in/" id="mba">MBA</a>
# <a class="nava awes" href="mca.html" id="mca">MCA</a>
# <ul class="navali">
# <li class=" nava divider" id=""></li>
# </ul>
# <a class="nava awes" href="physics.html" id="physics">Physics</a>
# <a class="nava awes" href="chemistry.html" id="chemistry">Chemistry</a>
# <a class="nava awes" href="mathematics.html" id="mathematics">Mathematics</a>
# <ul class="navali">
# <li class=" nava divider" id=""></li>
# </ul>
# <a class="nava" href="hr.html" id="hr">Placements &amp; HR</a>
# </div>
# </li>
# <li class="navali"><a class="dropNav1">Others<i class="material-icons right md">arrow_drop_down</i></a></li>
# <li class="innerli">
# <div class="innerNav1">
# <a class="nava" href="alumni.html" id="alum">Alumni</a>
# <a class="nava" href="admissions.html" id="admission">ADMISSIONS &amp; OFFICE</a>
# <a class="nava" href="cultural.html" id="faci">Cultural</a>
# <a class="nava" href="facilities.html" id="faci">Facilities</a>
# </div>
# </li>
# </ul>
# </div>
# </nav>
# <div class="container">
# <h5 align="center" class="head-style avoid-nav">COMPUTER SCIENCE ENGINEERING</h5>
# <!-- the below Added on 10 Jul 2018 -->
# <a href="images/cse/dept_profile.pdf" target="_blank">
# <h5 align="center" class="rns-head">Department Profile</h5> </a>
# <!-- the above added on 10 Jul 2018 -->
# <div class="row">
# <div class="col s12 m3">
# <div class="card">
# <div class="card-image">
# <img src="https://hisjia.bn1304.livefilestore.com/y4mVqhISz4SaXkb4-g7dduWxT0YsNiYQoaJL6vf8Jb-a33TgiGLwSZqBBtDMbQypQdouuqdm67TGDlREOcqWug8xa-URZrFPVH7y-TyjDrdQZjvoXAKXdn0xFnbplT0vl_XmVZ2uji9Ibem-m44BVTU5_ps5S6V0wAh-GV6FZ9mv9phMsUBRt-z5jNbzqkskLlxTE6YUMp2XmkAXh8RNWZy3w?width=660&amp;height=440&amp;cropmode=none" width="660"/>
# <span class="card-title"></span>
# </div>
# <div class="card-content">
# <span class="card-name">Dr.G T Raju</span>
# <div><span class="card-info">Vice-Principal, Professor and Head of CSE</span></div>
# </div>
# </div>
# </div>
# <p>The department of Computer Science and Engineering was established in the year 2001 right from the inception of the Institution with an objective of imparting quality technical education in IT field. The department is currently headed by Dr. G T Raju who has more than 25 years of experience in the field. The department offers BE and M.Tech degrees in Computer Science and Engineering (CSE) with an intake 120 UG students and 24 PG students respectively. The department has a VTU recognized R&amp;D centre and currently 18 research scholars are pursuing their research work leading to PhD/MSc (Engg) degrees. The department has state-of-the-art laboratories, library facility for staff &amp;students and boasts of well trained, committed and experienced teaching faculty with an average teaching experience of 10.04 years, who emphasize the theoretical and practical applications of computation and computer systems to the needs of society.</p>
# <p>The department is striving hard to make the unique spirit of RNSIT, an Institution with a difference by promoting excellence in Teaching, Research and Services covering the fundamentals as well as applied aspects of Computer Science and IT.</p>
# <p>The fast changing scenario in Computer Science and Engineering necessitates the department to actively extend its focus and activities in</p>
# <ol>
# <li>Research and Development</li>
# <li>Consultancy in IT related areas and Sponsored projects apart from its excellent conventional UG and PG teaching.</li>
# </ol>
# <p>Being a forerunner in the field of technology, the department envisages evolving as a center of excellence to adapt itself to the rapid advancements in various specialized fields. Computer Science and Engineering continues to be the driving force of the nation's economy in the fields of science and technology. We in the CSE department, at RNSIT, are very excited to be part of this information revolution.</p>
# <div class="row">
# <div class="col s12 m6">
# <h4 class="black-text"><b></b></h4><p>Vision</p> Preparing Better Computer Professsionals for a Real World.
#                 </div>
# <div class="col s12 m6">
# <h4 class="black-text"><b></b></h4><p>Mission</p>
# <ol>
# <li>Imparting solid foundations and applied aspects in both Computer Science Theory and  Programming practices</li>
# <li>Providing training and encouraging R &amp; D and Consultancy Services in frontier areas  of Computer Science and Engineering with a Global outlook </li>
# <li>Fostering the highest ideals of ethics, values and creating awareness of the  role of Computing in Global Environment</li>
# <li>Educating and preparing the graduates, highly sought after, productive, and well-respected for their work culture</li>
# <li>Supporting and inducing lifelong learning</li>
# </ol>
# </div>
# </div>
# <div class="row">
# <h4 class="black-text"><b></b></h4><p>Objectives/Goals</p>
# <div class="col s12 m6">
# <h5 class="black-text"><b></b></h5><p>Short Range</p>
# <ol>
# <li>To build and use modern aids for effective teaching</li>
# <li>To modernize the Laboratories with state-of-the-art software, hardware, Interfacing and networking components</li>
# <li>To ensure all-round development of students through conduction of self-sustained training programs</li>
# <li>To organize and conduct short-term courses/workshops/FDPs/seminars on recent trends in IT at National and International levels on regular basis</li>
# </ol>
# </div>
# <div class="col s12 m6">
# <h5 class="black-text"><b></b></h5><p>Long Range</p>
# <ol>
# <li>To become part of the Industry and Research organizations at National and International levels
#                             <ol>
# <li>To promote Industry-Institute Interactions through projects, consultancy and executive development programs</li>
# <li>To promote research and development activities in the frontier areas of Computer Science and engineering</li>
# </ol>
# </li>
# <li>To enter into understanding with globally renowned Universities</li>
# <li>To develop Centers of Excellence in core areas
#                             <ol>
# <li>Artificial Intelligence and Machine Learning</li>
# <li>Internet of Things, Digital/Device Mesh, User Experience</li>
# </ol>
# </li>
# <li>To strengthen Entrepreneurship Development Cell
#                             <ol>
# <li>To provide necessary strengths for enabling the students to innovate and become entrepreneurs</li>
# </ol>
# </li>
# </ol>
# </div>
# </div>
# <h4 class="black-text"><b></b></h4><p>Laboratory</p>
# <div class="slider">
# <ul class="slides">
# <li>
# <img src="images/cse/lab1.jpg" width="960"/>
# </li>
# <li>
# <img src="images/cse/lab2.jpg" width="960"/>
# </li>
# <li>
# <img src="images/cse/lab3.jpg" width="960"/>
# </li>
# </ul>
# </div>
# </div>
# <div class="row">
# <ul class="collapsible popout" data-collapsible="accordion">
# <li>
# <div class="collapsible-header"><i class="material-icons">location_city</i><b>FACILITIES AND INFRASTRUCTURE</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>Adequate Infrastructure: 9 state-of-the-art laboratories - 298 latest branded computers, departmental library, Seminar Hall, Well furnished class rooms</li>
# <li>Licensed Softwares and internet of 75 mbps dedicated  line with Wi-Max connectivity</li>
# <li>Exclusive Computer Lab for M.Tech-CSE with 24 Computers</li>
# <li>Departmental library with 369 Titles and 542 books, 350+ Project reports, e-Journals</li>
# <li>A Seminar hall with 80 seats, EDUSAT hall with 400 seats and 10 well-furnished Class Rooms</li>
# <li>27 qualified and committed faculties - 3 Professors, 3 Associate Professors, 21 Assistant Professors with an average experience of more than 13.23 years</li>
# <li>Faculty to Student ratio of 1:18</li>
# <li>11 faculties are pursuing PhD and published more than 105 papers in the last three years</li>
# <li> Faculty members in diversified areas with Research motivation</li>
# <li> Faculty involvement in conducting Conferences, Seminars, and Workshops.</li>
# <li>Participation in University activities / Other Autonomous Institutions / Curriculum update, BOE members, BOS members, LIC Committee members</li>
# <li>Bagged Best Teacher awards: Dr. Kiran P, Prof. Hemanth S, and Dr. G T Raju</li>
# <li>Very good consistent pass percentage in University exams &gt; 85%</li>
# <li>More than 90% Placement for UG and PG students, Internships at reputed Industries for Project works</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">work</i><b>INTERNAL QUALITY ASSURANCE CELL</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <a href="images/cse/iqac_rnsit.pdf" target="_blank">
# <ol>
# <li> Internal Quality Assurance Cell</li>
# </ol> </a>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">poll</i><b>STUDENTS ACHIEVEMENTS</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <a href="images/cse/students_achievements.pdf" target="_blank">
# <ol>
# <li> Students Achievements and Accolades</li>
# </ol> </a>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">receipts</i><b>DEPARTMENT PEO,PO AND PSO</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <a href="images/cse/department_peo_po_pso.pdf" target="_blank">
# <ol>
# <li> PEO PO AND PSO</li>
# </ol> </a>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">thumb_up</i><b>OTHER EXCELLENCE AND ACHIEVEMENTS</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>National/International conferences and won awards/prizes. </li>
# <li>4 papers presented at 31st CSI convention held at JSSATE, Bangalore, Mar 2017, Best Paper Award </li>
# <li>3 papers presented at 30th CSI convention held at SIT, Tumkur, Feb 2016, Best Paper Award </li>
# <li>6 papers presented at 29th CSI convention held at KSIT, Bangalore, Jan 2015, Best Paper Award </li>
# <li>Mr.Harshit N L and Mr. Adithya Mr.Arjun K P have won first prize in National Conference on Computing Technologies and Trends,(NCCTT) Mr.Anirudh S,Mr.Ganapati V S and Mr. Karthik have been appreciated with Consolation Prize Mr. Mayukh Das, of 2012 batch CSE, secured the second place in the technical quiz &amp;on spot programming in C++. </li>
# <li>Ms. Nivedita Priyadarshini, of 2012 batch CSE, got the consolation prize for the paper titled Localization of Algorithms in Wireless Sensor Networks in paper presentation.</li>
# <li>Sreevatsa KV of 4<sup>th</sup> Sem won the best paper award along with cash prize of 1500/- at Institution of Engineers(India) Students's Technical Paper presentation and project model exhibiyion IEINITTE-2016 conducted by Indian Institute of Engineers at NMAMIT, Nitte on 5<sup>th</sup> March 2016.</li>
# <li>Prateek Prasad of 4<sup>th</sup>CSE received a scholorship of 1.2 Lakhs from Google India for "Android Developer"-Nanodegree course.</li>
# <li>Student Internships:
#                                 <ol>
# <li>Ramesh S M at IBM, Bangalore with Stipend of 20000/-</li>
# <li>Sai Teja T at ThoughtWorks, Bangalore with Stipend of 20000/-</li>
# <li>Sachin P, Niranjan B, Akash, Sujay and Pooja K P at Samsung R&amp;D Bangalore with Stipend of 35000/- </li>
# </ol>
# </li>
# <li>Students with very high scores/percentile in Competitive Exams like GATE, GRE and CAT : 35th AIR @ GATE, 98 percentile @ CAT, 325 score @ CAT.</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">receipts</i><b>DEPARTMENT COURSE OUTCOMES</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <a href="images/cse/COs.pdf" target="_blank">
# <ol>
# <li> COs</li>
# </ol> </a>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">people</i><b>WORKSHOPS/CONFERENCES CONDUCTED</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>1st International Conference on Data Engineering &amp;Communication Systems ICDECS-2011 30-31, Dec 2011 Two days 400 Participated,105 research scholars presented papers and published in conference proceedings, Supported by Accenture, Infosys, VTU, Canara Bank, Atria IT, Escube, Acharya IT, RNSIT</li>
# <li>2nd International Conference on Data Engineering and Communication Systems ICDECS-2015 28-29 , Dec 2015 Two days 260 Participated, 82 research scholars presented papers and published in scopus indexed journal- IJAER , Supported by CSI,VTU, Orange Computers, Canara Bank, Wiley, Universities Press</li>
# <li>Have got admission to higher studies ( MS / PhD) in International renowned Institutions</li>
# <li>BALAJI , UNIVERSITY OF WISCOSIN, MILWAUKI , P h.D COMPUTER SCIENCE</li>
# <li>Vi56 Workshops/FDPs Organized</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">receipts</i><b>VTU CURRICULUM </b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <a href="images/cse/Syllabus-VTU.rar" target="_blank">
# <ol>
# <li>VTU CURRICULUM</li>
# </ol> </a>
# </div>
# </li>
# <li>
# </li><li>
# <div class="collapsible-header"><i class="material-icons">event_available</i><b>EXTRA CURRICULAR EVENTS/ACTIVITIES</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>Mr.Mayukh Das, of 2012 batch CSE, secured the second place in the technical quiz &amp;on spot programming in C++.</li>
# <li>Ms. Nivedita Priyadarshini, of 2012 batch CSE, got the consolation prize for the paper titled Localization of Algorithms in Wireless Sensor Networks in paper presentation.</li>
# <li>Good Academic and Extra, Co-Curricular records by students, Consistent performance in university exams and placement of the students in Core Companies .</li>
# <li> Good number of Paper Publications by both Faculty and Students.</li>
# <li>Good number of technical interactions like Guest Lectures, Workshops, Competitions &amp; Conferences are conducted by the Department.</li>
# <li>Students Club AIKYA, Robotics Club, mini project exhibition(PROP), Professional societies IEEE, CSI &amp;ISTE for the benefit of faculty and students to alert their skills.</li>
# <li>Training Classes are carried out to prepare the students for Placements/GATE /GRE Examination.</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">monetization_on</i><b>SPONSORED RESEARCH PROGRAM DETAILS</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>Completed two Research Projects 3.8 Lakhs for the research project entitled Diagnosis Tool for Assessment of Lung Nodules that helps in Analyzing Tumors with the aid of CT Image Databases using CBIR Techniques under VTU Research Grants Scheme, for a period of 2 years . Ref: VTU/Aca/2011-12/A-9/844 dated 8 May 2012.</li>
# <li>5.2 Lakhs for the research project entitled System for Image Retrieval from Medical Image Databases by associating Content and Semantic of Images, under AICTE Research Grants Scheme, for a period of 2 years during April 2012</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">poll</i><b>PERFORMANCE</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>Quality Input : CET ranks :
#                                 &lt; 2500 and COMED-K ranks : &lt; 6000</li>
# <li>Faculty: Boasts of well qualified, committed and experienced teaching faculty - 2 Professors, 3 Asso. Professors, 21 Asst. Professors </li>
# <li>Faculty to Student ratio 1:16, with an average teaching experience 10.6 years.</li>
# <li>Faculty members in diversified areas with Research motivation.</li>
# <li>Faculty involvement in conducting Conferences, Seminars, and Workshops. Participation in University activities/ Other Institutions â€œ Curriculum update, BOE members, BOS members, LIC Committee members at University and Autonomous Institutions.</li>
# <li>Results and Placements: Consistent pass percentage in University exams &gt; 85 % and Placement &gt; 95%.</li>
# <li>Paper Publications: Faculty: &gt; 105 (last three years) Students: &gt; 87 (last three years from both UG and PG)</li>
# <li>Produced 8 Doctorates, Completed 2 R&amp;D Projects.</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">message</i><b>NEWSLETTER(S) DESCRIPTON</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>AIKYA - Annual departmental newsletter, 6 editions so far covers major achievements of our students and faculty, technical articles etc., </li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">work</i><b>PROJECT OPEN HOUSE</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <ol>
# <li>Every year during May, the department orgnaizes a Project Open House Panoram for all the students where in they showcase their projects. Industry and academia people will evaluate the quality of projects and award the best project awards.
#                                 </li>
# <li>Project Open House Panorama-2016(PROP)- Intercollegiate Project Exhibition 6th May 2016, One day, total of 40 groups presented.</li>
# <li>Project Open House Panorama-2017(PROP)- Intercollegiate Project Exhibition 11th May 2017, One day, total of 42 groups presented .</li>
# </ol>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">directions_run</i><b>SPORTS PARTICIPATION</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body"><span>
#         Our students have represented university and state in Sports, Technical and Cultural events, won awards and also actively participated in cultural &amp; sports activities in the intra collegiate fest</span>
# </div>
# </li>
# <li>
# <div class="collapsible-header"><i class="material-icons">receipts</i><b>R &amp;D WORK / PAPERS PUBLISHED</b>
# <!--i class="material-icons right_icons">arrow_drop_down</i-->
# </div>
# <div class="collapsible-body">
# <table class="responsive-table">
# <tr>
# <td>No. of Candidates Registered </td>
# <td>No. of Research Supervisors </td>
# <td>Total no. of Publications </td>
# <td>No. of Workshops attended </td>
# <td>No. of Workshops/ Seminars Organized </td>
# <td>No. of Doctral Candidates Produced</td>
# </tr>
# <tr>
# <td>28 ( 27 PhD + 1 MSc (Engg)</td>
# <td> 06</td>
# <td>105 in the last three years</td>
# <td> 51 in the last three years</td>
# <td> 24 </td>
# <td>08</td>
# </tr>
# </table>
# <ul>
# <b>Research Projects Completedunder VTU / AICTE Research Grants:</b>
# <li>3.8 Lakhs for the research project entitled Diagnosis Tool for Assessment of Lung Nodules that helps in Analyzing Tumors with the aid of CT Image Databases using CBIR Techniques under VTU Research Grants Scheme, for a period of 2 years . Ref: VTU/Aca/2011-12/A-9/844 dated 8 May 2012.
#                                 </li>
# <li>5.2 Lakhs for the research project entitled System for Image Retrieval from Medical Image Databases by associating Content and Semantic of Images , under AICTE Research Grants Scheme, for a period of 2 years during April 2012.</li>
# </ul>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <h4 class="black-text"><b></b></h4><p>Teaching Staff</p>
# <ul class="listul cardul">
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal1"><img src="images/cse/1.jpg" width="660"/>
# <p> Dr. G. T. Raju</p>
# <p> Vice-Principal, Professor and Head of CSE</p>
# </a>
# </li>
# <div class="modal" id="modal1">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/1.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.G T Raju</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Vice-Principal, Professor and Head of CSE</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE(CSE), ME(CSE), PhD</td>
# </tr>
# <td>Total Experience</td>
# <td>25+ years of teaching, 1 year of industry, 14+ years of research</td>
# <tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# <td>Research and Guidance</td>
# <td>12 PhDs, 2 Scholars submitted thesis, 5 PhD students being guided</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>
#                                                 Data Mining, Web Mining Image Processing, Prefetching and Caching, Information Retrieval
#                                             </td>
# </tr>
# <tr>
# <td>Projects</td>
# <td>Guided 86 UG students' projects, 36 PG students' projects, 12 MCA students' projects 4 Research Projects under Grants from AICTE, VTU</td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Published 65+ papers at reputed indexed International Journals, 45+ papers at reputed Intrrnational Conferences and 6 at National conferences</td>
# </tr>
# <tr>
# <td>No of Books Published</td>
# <td>5</td>
# </tr>
# <tr>
# <td>FDPs, Conferences, Seminars and Talks</td>
# <td>35+ FDP conferences organized, 60+ Worshops attended, 36+ National and International conferences attended, 39+ Talks delivered</td>
# </tr>
# <tr>
# <td>Projects Managed</td>
# <td>86+ Projects for UG students, 48+ Projects for PG students, 15+ Projects for MCA students</td>
# </tr>
# <tr>
# <td>Research Grants</td>
# <td>12 Lakhs as reseacrh grant from AICTE under MODROB scheme during 1995/96, 9 Lakhs from VTU and AICTE under research grant scheme during 2011/12</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Best Teacher Award and Rajiv Gandhi Gold Medal</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal44"><img src="images/mca/1.jpg" width="960"/>
# <p>Dr.Kavya Naveen</p>
# <p>Professor</p>
# </a>
# </li>
# <div class="modal" id="modal44">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/mca/1.jpg" width="960"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name:</td>
# <td> Dr.Kavya Naveen</td>
# </tr>
# <tr>
# <td>Email:</td>
# <td> n.p.kavya@rnsit.ac.in</td>
# </tr>
# <tr>
# <td>Designation:</td>
# <td>Professor</td>
# </tr>
# <tr>
# <td>Qualification:</td>
# <td>Ph.D In CSE</td>
# </tr>
# <tr>
# <td>Areas of interest:</td>
# <td>Big Data Analytics, Data Science, Data Mining &amp;Warehousing</td>
# </tr>
# <tr>
# <td>Projects:</td>
# <td>
# <ul>
# <li>Guided Projects for BE/MCA/Mtech candidates</li>
# <li>
#                                         Project on Privacy Preservation in Data Mining</li>
# <li>
#                                         Big data analysis for centimental data representation</li>
# <li>
#                                         Process mining for server central logs at SET Labs , Infosys Pvt, Ltd, E-city , Bangalore Video Denoising</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>Papers:</td>
# <td>Published 57 research papers in various Intrenational conferences /Journals which includes IEEE, Springer, Elsivier, ACM, Scopus Indexed with high Impact factor.</td>
# </tr>
# <tr>
# <td>Books written:</td>
# <td>
# <ul>
# <li>1.Dr.N P Kavya, Database Management Systems ,Thakur Publishers ISBN: 978-93-83922-26-0 , First Edition 2015</li>
# <li>
#                                         2. Dr.N .P Kavya , Database Management Systems, Thakur Publishers, ISBN:978-93-83922-260 ,Second Edition 2017</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>Total Experience:</td>
# <td>23 Years</td>
# </tr>
# <tr>
# <td>Experience in RNSIT:</td>
# <td>15 Years</td>
# </tr>
# <tr>
# <td>Other Achievements:</td>
# <td>
# <ul>
# <li>LIC Committee member for VTU</li>
# <li>
#                                         BOE/BOS Chairman/member of VTU in CSE/MCA &amp;4 autonomous Institutions</li>
# <li>
#                                         Board of Advisory council member in various Colleges</li>
# <li>
#                                         Reviewer /TPC &amp;Advisory Board member for 20 international conference</li>
# <li>
#
#                                         Bharat Jyoti Award and Certificate of Excellence for remarkable achievements in field of Science and technology , on 29th August 2012 , at National Seminar on Economic Growth and National Integration, By IIFS , New Delhi, India.</li>
# <li>
#                                         Glory of India gold medal was awarded on 20th August 2012 , at National Seminar on Role of education in modern India, By International Institute of Success Awareness New Delhi, India.</li>
# <li>
#                                         Best Professor for academic excellence award at RNSIT Bangalore Organized around 30 workshops for students and 10 FDP programs for Faculty of colleges all over Karnataka</li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal2"><img src="images/cse/2.jpg" width="660"/>
# <p> Dr.Girijamma H A</p>
# <p> Professor</p>
# </a>
# </li>
# <div class="modal" id="modal2">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/2.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.Girijamma H A</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, MTech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>16 years of teaching, 2 years of industry, 9 years of research</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal3"><img src="images/cse/3.jpg" width="3286"/>
# <p>Dr.Shashidhara H R</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal3">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/3.jpg" width="3286"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.Shashidhara H R</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>25 years of teaching, 1 year of research</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>6</td>
# </tr>
# <td>
#                                         Areas Of Interest
#                                     </td>
# <td>
#                                         Data Mining, Web Mining</td>
# <tr>
# <td>Projects</td>
# <td>Published 50 UG projects and 30 PG projects</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal4"><img src="images/cse/4.jpg" width="660"/>
# <p> Dr.S Sathish Kumar</p>
# <p>Associate Professor</p>
# </a>
# </li>
# <div class="modal" id="modal4">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/4.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.S Sathish Kumar</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Associate Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>25 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>15 Years</td>
# </tr>
# <tr>
# <td>
#                                             Areas Of Interest
#                                         </td>
# <td>
#                                             Data Mining Bio-informatics Cloud Computing Internet of Things</td>
# </tr>
# <tr>
# <td>Projects</td>
# <td>Guided 2 projects for KSCST</td>
# </tr>
# <tr>
# <td>
#                                             Papers
#                                         </td>
# <td>Published 19 Papers in National and International magazines</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal5"><img src="images/cse/5.jpg" width="660"/>
# <p>Dr.Kiran P</p>
# <p>Associate Professor.</p>
# </a>
# </li>
# <div class="modal" id="modal5">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/5.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.Kiran P</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Associate Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>11 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>14 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>
#                                                 Cryptography, Randomization &amp;Anonymization methods in generalization, Indexing techniques and Design patterns, Data Mining, Database Management Systems
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Published 12 Papers in National and International Magazines</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Best Teacher Award in 2005 and 2006 in RNSIT</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal6"><img src="images/cse/6.jpg" width="660"/>
# <p> Mr.Hemanth S</p>
# <p>Associate Professor</p>
# </a>
# </li>
# <div class="modal" id="modal6">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/6.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Hemanth S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Associate Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>14 years of teaching, 2 years of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>14 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining
#                                             </td>
# </tr>
# <tr>
# <td>Projects</td>
# <td>Semantic analysis using Python NLTK</td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Published 1 Paper in National Magazines</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Best Teacher Award, Technical training for Placement</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal7"><img src="images/cse/7.jpg" width="660"/>
# <p> Mr.Bhavani Shankar.K</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal7">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/7.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Bhavani Shankar.K</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>13 years of teaching, 5 years of industry</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal8"><img src="images/cse/8.jpg" width="660"/>
# <p> Mr.Anjan Kumar K. N</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal8">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/8.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Anjan Kumar K. N</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>15 years of teaching, 3 years 5 months of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>9 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>
#                                                 Network Security, IOT Protocol Stack, Data Mining
#                                             </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal9"><img src="images/cse/9.jpg" width="660"/>
# <p> Mrs.Sudhamani M J</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal9">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/9.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Sudhamani M J</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>13 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>13 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Image Processing and pattern Recognitions, Computer Architecture
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Publised 7 Papers in National and International Magazines</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal10"><img height="180" src="images/cse/mamatha_jajur.jpg" width="225"/>
# <p> Mrs.Mamatha Jajur</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal10">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" height="180" src="images/cse/mamatha_jajur.jpg" width="225"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Mamatha Jajur</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <!-- <tr>
#                       <td>Total Experience</td>
#                       <td>10 Years</td>
#                     </tr>
#                     <tr>
#                       <td>Experience in RNSIT</td>
#                       <td>10 Years</td>
#                     </tr> -->
# <!-- <tr>
#                       <tr>
#                         <td>
#                           Areas Of Interest
#                         </td>
#                         <td>Artificial Intelligence, Neural Networks, Embedded Computing Systems
#                         </td>
#                       </tr>
#                       <tr>
#                         <td>
#                           Projects
#                         </td>
#                         <td>Intranet Chatting, RTOS Sytem Application,Embedded Computing Systems</td>
#                       </tr> -->
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal70"><img height="180" src="images/cse/manjula_l.jpg" width="225"/>
# <p> Mrs.Manjula L</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal70">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" height="180" src="images/cse/manjula_l.jpg" width="225"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Manjula L</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <!-- <tr>
#                       <td>Total Experience</td>
#                       <td>10 Years</td>
#                     </tr>
#                     <tr>
#                       <td>Experience in RNSIT</td>
#                       <td>10 Years</td>
#                     </tr> -->
# <!-- <tr>
#                       <tr>
#                         <td>
#                           Areas Of Interest
#                         </td>
#                         <td>Artificial Intelligence, Neural Networks, Embedded Computing Systems
#                         </td>
#                       </tr>
#                       <tr>
#                         <td>
#                           Projects
#                         </td>
#                         <td>Intranet Chatting, RTOS Sytem Application,Embedded Computing Systems</td>
#                       </tr> -->
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal11"><img src="images/cse/11.jpg" width="660"/>
# <p> Mr.Sanjay P Kalas</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal11">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/11.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Sanjay P Kalas</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>10 years of teaching</td>
# </tr><tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                     Areas Of Interest
#                                                 </td>
# <td>Data Mining,Wireless Sensor Networks,IOT
#                                                 </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal12"><img src="images/cse/12.jpg" width="660"/>
# <p>Mrs.Mahima M Katti</p>
# <p>Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal12">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/12.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Mahima M Katti</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>11.75 years of teaching</td>
# </tr><tr>
# <td>Experience in RNSIT</td>
# <td>3.25 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                     Areas Of Interest
#                                                 </td>
# <td>Network Security, Wireless Networks, Applications of Microprocessors,
#                                                 </td>
# </tr>
# <tr>
# <td>
#                                                     Papers
#                                                 </td>
# <td>2 papers (Where?)</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal13"><img src="images/cse/13.jpg" width="660"/>
# <p> Mrs.Swathi G</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal13">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/13.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Swathi G</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.Tech, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>10 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Software Testing
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>An Enhanced Healthcare systems</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal14"><img src="images/cse/14.jpg" width="660"/>
# <p> Mr.Devaraj B. M</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal14">
# <div class="modal-content">
# <div class="modal-back">
# ...
# <td>Ms.Rashmi M</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td> 2 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>2 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>MANETS, Data Mining, Neural Networks</td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Artificial Intelligence and Stimulus Response System , Implementation of One-to-One Optimization Technique to Improve Data Storage in MANETS</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal24"><img src="images/cse/24.jpg" width="660"/>
# <p> Mr.Shrinivas Biradar</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal24">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/24.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Shrinivas Biradar</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>4.5 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>1 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Web Mining</td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Fatigue meter, Biospec</td></tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal26">
# <img src="images/cse/25.jpg" style="left: 0px; top: 0px" width="3389"/>
# <p> Ms.Chethana H R</p>
# <p> Assistant Professor</p>
# </a>
# </li>
# <div class="modal" id="modal26">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/25.jpg" width="3389"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Ms.Chethana H R</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>1 Year of teaching, 8.5 years of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>1 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining</td>
# </tr>
# <tr>
# <td>Papers</td>
# <td>
#                                                 3 Papers in National Journals
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Maximixing the efficiency of wireless networks</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Received Bravo Award at IBM for excellent performance, Completed IBM DB2 certification in 2007, Received BEST PAPER AWARD for presenting my research work on Attribute Based Access for Information Sharing Networks in Cloud at Third National Conference On Wireless Control &amp; Communication Technologies conducted by Department of Telecommunication Engineering, Dr AIT, Bangalore. "
#                                             </td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# </ul>
# </div>
# </div>
# <div class="container">
# <div class="row">
# <h4 class="black-text"><b></b></h4><p>Non-Teaching Staff</p>
# <ul class="listul cardul">
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal27"><img src="images/cse/26.jpg" width="660"/>
# <p>Mr.R Sundar Krishna</p>
# <p>System Analyst</p>
# </a>
# </li>
# <div class="modal" id="modal27">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/26.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.R Sundar Krishna</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>System Analyst</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE, MS</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>23 years of teaching</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal28"><img src="images/cse/27.jpg" width="660"/>
# <p>Mrs.Deepa S</p>
# <p>Programmer</p>
# </a>
# </li>
# <div class="modal" id="modal28">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/27.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Deepa S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Programmer</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE,(M.Tech)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>7 years of teaching</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal29"><img src="images/cse/28.jpg" width="660"/>
# <p>Mr.Ravikiran M Devadiga T</p>
# <p>Programmer</p>
# </a>
# </li>
# <div class="modal" id="modal29">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/28.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Ravikiran M Devadiga T</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Programmer</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE,(M.Tech)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>2 years of teaching</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal30"><img src="images/cse/29.jpg" width="660"/>
# <p>Mrs.Mamatha P K</p>
# <p> Assistant Instructor</p>
# </a>
# </li>
# <div class="modal" id="modal30">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/29.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Mamatha P K</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Instructor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>Diploma in CS</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>2 years of teaching</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# <!-- </div>
#                                       <li class="cardli">
#                                         <a class="waves-effect waves-light" href="#modal31"><img src="images/cse/30.jpg" width="660" />
#                                           <p>Mr. Kartik Hegde</p>
#                                           <p>Semi Skilled Lab Assistant</p>
#                                         </a>
#                                       </li>
#                                       <div id="modal31" class="modal">
#                                         <div class="modal-content">
#                                           <div class="modal-back">
#                                             <img class="modal-img" src="images/cse/30.jpg" width="660" />
#                                           </div>
#                                           <div class="modal-details">
#                                             <table>
#                                               <tbody>
#                                                 <tr>
#                                                   <td>Name</td>
#                                                   <td>Mr. Kartik Hegde</td>
#                                                 </tr>
#                                                 <tr>
#                                                   <td>Designation</td>
#                                                   <td>Semi Skilled Lab Assistant</td>
#                                                 </tr>
#                                                 <tr>
#                                                   <td>Qualification</td>
#                                                   <td>DEC,(CCNA),(B.E),MCITP</td>
#                                                 </tr>
#                                                 <tr>
#                                                   <td>Total Experience</td>
#                                                   <td>9 years of teaching</td>
#                                                 </tr>
#                                               </tbody>
#                                             </table>
#                                           </div>
#                                         </div>
#                                         <div class="modal-footer">
#                                           <a href="#!" class=" modal-action modal-close waves-effect waves-green btn-flat">Close</a>
#                                         </div> -->
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal33"><img src="images/cse/31.jpg" width="660"/>
# <p> Mr.Vinayak P H</p>
# <p>Semi Skilled Lab Assistant</p>
# </a>
# </li>
# <div class="modal" id="modal33">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/31.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Vinayak P H</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Semi Skilled Lab Assistant</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BA, A+,N+ (MCA)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>9 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal34"><img src="images/cse/32.jpg" width="660"/>
# <p>Mr.Rajesh</p>
# <p>Semi Skilled Lab Assistant</p>
# </a>
# </li>
# <div class="modal" id="modal34">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/32.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Rajesh</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Semi Skilled Lab Assistant</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC, DEC,(BE)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>7 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal36"><img src="images/cse/33.jpg" width="660"/>
# <p>Mr.Nagendra T P</p>
# <p>Semi Skilled Lab Assistant</p>
# </a>
# </li>
# <div class="modal" id="modal36">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/33.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Nagendra T P</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Semi Skilled Lab Assistant</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC, DCH,(BA)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>19 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal37"><img src="images/cse/34.jpg" width="660"/>
# <p>Mr.Radhakrishna B S</p>
# <p>Helper</p>
# </a>
# </li>
# <div class="modal" id="modal37">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/34.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Radhakrishna B S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Helper</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.A., B.L.I.Sc</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>20 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal38"><img src="images/cse/35.jpg" width="660"/>
# <p>Mr.Ganapathi</p>
# <p>Helper</p>
# </a>
# </li>
# <div class="modal" id="modal38">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/35.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Ganapathi</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Helper</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC,(B.Sc(IT))</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>4 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal39">
# <img src="images/cse/36.jpg" style="left: -96px; top: -4160px" width="660"/>
# <p>Mr.Vithal M</p>
# <p>Attender</p>
# </a>
# </li>
# <div class="modal" id="modal39">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/36.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Vithal M</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Attender</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC,(BA)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>4 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# <li class="cardli">
# <a class="waves-effect waves-light" href="#modal40">
# <img src="images/cse/37.jpg" style="left: 0px; top: 0px" width="660"/>
# <p>Mr.Krishna Murthy</p>
# <p>Peon</p>
# </a>
# </li>
# <div class="modal" id="modal40">
# <div class="modal-content">
# <div class="modal-back">
# <img class="modal-img" src="images/cse/37.jpg" width="660"/>
# </div>
# <div class="modal-details">
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Krishna Murthy</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Peon</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>SSLC</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>3 years</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="modal-footer">
# <a class=" modal-action modal-close waves-effect waves-green btn-flat" href="#!">Close</a>
# </div>
# </div>
# </ul>
# </div>
# </div>
# <div id="fot">
# <footer class="page-footer" id="footer">
# <div class="container-fluid">
# <div class="row lool">
# <div class="roww" style="overflow: hidden;">
# <a href="https://www.facebook.com/pages/RNS-Institute-of-Technology/143512852331957">
# <image alt="fb" class="icon ic1" src="images/facebook.svg">
# </a>
# <a href="" onclick="insta()">
# <image alt="insta" class="icon in12" src="images/instagram.svg">
# </a>
# <a href="mailto:rnsitplacement@gmail.com">
# <image alt="gmail" class="icon" src="images/gmail.svg">
# </a>
# <a href="https://www.twitter.com/RNSIT_Bangalore/">
# <image alt="twitter" class="icon ic3" src="images/twitter.svg">
# </a>
# <a href="https://www.linkedin.com/in/rnsit-bangalore-00765014b/">
# <image alt="linkedin" class="icon ic4" src="images/linkedin.svg">
# </a>
# </div>
# <p class="cotxt" style="text-align:center"><b>Maintained by Dept of ISE</b></p>
# </div>
# </div>
# </footer>
# </div>
# <!-- Modal end -->
# <script src="js/dept.js" type="text/javascript"></script>
# <script src="js/navbar.js" type="text/javascript"></script>
# <script src="js/modal.js" type="text/javascript"></script>
# </body>
# </html>

# %%
find_table_tag=soup.find_all('table')
find_table_tag[1]

for i in range(len(find_table_tag)):
    if (i>0):
        print(find_table_tag[i])
#find_p_tag[11].string
# Out:
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.G T Raju</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Vice-Principal, Professor and Head of CSE</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE(CSE), ME(CSE), PhD</td>
# </tr>
# <td>Total Experience</td>
# <td>25+ years of teaching, 1 year of industry, 14+ years of research</td>
# <tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# <td>Research and Guidance</td>
# <td>12 PhDs, 2 Scholars submitted thesis, 5 PhD students being guided</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>
#                                                 Data Mining, Web Mining Image Processing, Prefetching and Caching, Information Retrieval
#                                             </td>
# </tr>
# <tr>
# <td>Projects</td>
# <td>Guided 86 UG students' projects, 36 PG students' projects, 12 MCA students' projects 4 Research Projects under Grants from AICTE, VTU</td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Published 65+ papers at reputed indexed International Journals, 45+ papers at reputed Intrrnational Conferences and 6 at National conferences</td>
# </tr>
# <tr>
# <td>No of Books Published</td>
# <td>5</td>
# </tr>
# <tr>
# <td>FDPs, Conferences, Seminars and Talks</td>
# <td>35+ FDP conferences organized, 60+ Worshops attended, 36+ National and International conferences attended, 39+ Talks delivered</td>
# </tr>
# <tr>
# <td>Projects Managed</td>
# <td>86+ Projects for UG students, 48+ Projects for PG students, 15+ Projects for MCA students</td>
# </tr>
# <tr>
# <td>Research Grants</td>
# <td>12 Lakhs as reseacrh grant from AICTE under MODROB scheme during 1995/96, 9 Lakhs from VTU and AICTE under research grant scheme during 2011/12</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Best Teacher Award and Rajiv Gandhi Gold Medal</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name:</td>
# <td> Dr.Kavya Naveen</td>
# </tr>
# <tr>
# <td>Email:</td>
# <td> n.p.kavya@rnsit.ac.in</td>
# </tr>
# <tr>
# <td>Designation:</td>
# <td>Professor</td>
# </tr>
# <tr>
# <td>Qualification:</td>
# <td>Ph.D In CSE</td>
# </tr>
# <tr>
# <td>Areas of interest:</td>
# <td>Big Data Analytics, Data Science, Data Mining &amp;Warehousing</td>
# </tr>
# <tr>
# <td>Projects:</td>
# <td>
# <ul>
# <li>Guided Projects for BE/MCA/Mtech candidates</li>
# <li>
#                                         Project on Privacy Preservation in Data Mining</li>
# <li>
#                                         Big data analysis for centimental data representation</li>
# <li>
#                                         Process mining for server central logs at SET Labs , Infosys Pvt, Ltd, E-city , Bangalore Video Denoising</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>Papers:</td>
# <td>Published 57 research papers in various Intrenational conferences /Journals which includes IEEE, Springer, Elsivier, ACM, Scopus Indexed with high Impact factor.</td>
# </tr>
# <tr>
# <td>Books written:</td>
# <td>
# <ul>
# <li>1.Dr.N P Kavya, Database Management Systems ,Thakur Publishers ISBN: 978-93-83922-26-0 , First Edition 2015</li>
# <li>
#                                         2. Dr.N .P Kavya , Database Management Systems, Thakur Publishers, ISBN:978-93-83922-260 ,Second Edition 2017</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td>Total Experience:</td>
# <td>23 Years</td>
# </tr>
# <tr>
# <td>Experience in RNSIT:</td>
# <td>15 Years</td>
# </tr>
# <tr>
# <td>Other Achievements:</td>
# <td>
# <ul>
# <li>LIC Committee member for VTU</li>
# <li>
#                                         BOE/BOS Chairman/member of VTU in CSE/MCA &amp;4 autonomous Institutions</li>
# <li>
#                                         Board of Advisory council member in various Colleges</li>
# <li>
#                                         Reviewer /TPC &amp;Advisory Board member for 20 international conference</li>
# <li>
#
#                                         Bharat Jyoti Award and Certificate of Excellence for remarkable achievements in field of Science and technology , on 29th August 2012 , at National Seminar on Economic Growth and National Integration, By IIFS , New Delhi, India.</li>
# <li>
#                                         Glory of India gold medal was awarded on 20th August 2012 , at National Seminar on Role of education in modern India, By International Institute of Success Awareness New Delhi, India.</li>
# <li>
#                                         Best Professor for academic excellence award at RNSIT Bangalore Organized around 30 workshops for students and 10 FDP programs for Faculty of colleges all over Karnataka</li>
# </ul>
# </td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.Girijamma H A</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, MTech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>16 years of teaching, 2 years of industry, 9 years of research</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.Shashidhara H R</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>25 years of teaching, 1 year of research</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>6</td>
# </tr>
# <td>
#                                         Areas Of Interest
#                                     </td>
# <td>
#                                         Data Mining, Web Mining</td>
# <tr>
# <td>Projects</td>
# <td>Published 50 UG projects and 30 PG projects</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.S Sathish Kumar</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Associate Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>25 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>15 Years</td>
# </tr>
# <tr>
# <td>
#                                             Areas Of Interest
#                                         </td>
# <td>
#                                             Data Mining Bio-informatics Cloud Computing Internet of Things</td>
# </tr>
# <tr>
# <td>Projects</td>
# <td>Guided 2 projects for KSCST</td>
# </tr>
# <tr>
# <td>
#                                             Papers
#                                         </td>
# <td>Published 19 Papers in National and International magazines</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Dr.Kiran P</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Associate Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>11 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>14 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>
#                                                 Cryptography, Randomization &amp;Anonymization methods in generalization, Indexing techniques and Design patterns, Data Mining, Database Management Systems
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Published 12 Papers in National and International Magazines</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Best Teacher Award in 2005 and 2006 in RNSIT</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Hemanth S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Associate Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>14 years of teaching, 2 years of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>14 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining
#                                             </td>
# </tr>
# <tr>
# <td>Projects</td>
# <td>Semantic analysis using Python NLTK</td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Published 1 Paper in National Magazines</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Best Teacher Award, Technical training for Placement</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Bhavani Shankar.K</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>13 years of teaching, 5 years of industry</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Anjan Kumar K. N</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>15 years of teaching, 3 years 5 months of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>9 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>
#                                                 Network Security, IOT Protocol Stack, Data Mining
#                                             </td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Sudhamani M J</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>13 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>13 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Image Processing and pattern Recognitions, Computer Architecture
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Papers
#                                             </td>
# <td>Publised 7 Papers in National and International Magazines</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Mamatha Jajur</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <!-- <tr>
#                       <td>Total Experience</td>
#                       <td>10 Years</td>
#                     </tr>
#                     <tr>
#                       <td>Experience in RNSIT</td>
#                       <td>10 Years</td>
#                     </tr> -->
# <!-- <tr>
#                       <tr>
#                         <td>
#                           Areas Of Interest
#                         </td>
#                         <td>Artificial Intelligence, Neural Networks, Embedded Computing Systems
#                         </td>
#                       </tr>
#                       <tr>
#                         <td>
#                           Projects
#                         </td>
#                         <td>Intranet Chatting, RTOS Sytem Application,Embedded Computing Systems</td>
#                       </tr> -->
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Manjula L</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech, Ph.D-Pursuing</td>
# </tr>
# <!-- <tr>
#                       <td>Total Experience</td>
#                       <td>10 Years</td>
#                     </tr>
#                     <tr>
#                       <td>Experience in RNSIT</td>
#                       <td>10 Years</td>
#                     </tr> -->
# <!-- <tr>
#                       <tr>
#                         <td>
#                           Areas Of Interest
#                         </td>
#                         <td>Artificial Intelligence, Neural Networks, Embedded Computing Systems
#                         </td>
#                       </tr>
#                       <tr>
#                         <td>
#                           Projects
#                         </td>
#                         <td>Intranet Chatting, RTOS Sytem Application,Embedded Computing Systems</td>
#                       </tr> -->
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Sanjay P Kalas</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>10 years of teaching</td>
# </tr><tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                     Areas Of Interest
#                                                 </td>
# <td>Data Mining,Wireless Sensor Networks,IOT
#                                                 </td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Mahima M Katti</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>11.75 years of teaching</td>
# </tr><tr>
# <td>Experience in RNSIT</td>
# <td>3.25 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                     Areas Of Interest
#                                                 </td>
# <td>Network Security, Wireless Networks, Applications of Microprocessors,
#                                                 </td>
# </tr>
# <tr>
# <td>
#                                                     Papers
#                                                 </td>
# <td>2 papers (Where?)</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Swathi G</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.Tech, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>10 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Software Testing
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>An Enhanced Healthcare systems</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Devaraj B. M</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.E, (Ph.D)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>12 years of teaching,2 years of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>9 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Network Security, Data Mining
#                                             </td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Chandrashekar B S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>7 years of teaching, 4 years of industry</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Sampada K. S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>14 years of teaching, 3.5 years of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Text Mining, Big data, Networks</td>
# </tr>
# <tr>
# <td>Papers</td>
# <td>
#                                                 5 Papers in International Journals
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>1.iAgni Management System for Karnataka State Fire &amp;Emergency Services(KSFES) 2. ROSAT Student management and assessment system.</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Karanam Sunil Kumar</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>10 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>10 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Video tracking, Data Structures</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Ramyashree A N</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.Tech, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>12 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>11 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining, Computer Networks</td>
# </tr>
# <tr>
# <td>Papers</td>
# <td>
#                                                 2 Papers in International Journals and 2 in National Journals
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Performance analysis of iSCSI in a SAN using software based target and initiator e- basket Customer management
#                                             </td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Won Best Paper award at national conference-SJBIT 2010 STATE AWARD winner for essay writing on Global warming and it's consequences in 1998-1999 Member of Technical Training Team at RNSIT.</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Ms.Reshma Jakabal</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>8 years</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>5 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining, Big Data, Networking</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Chethan D S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>6 years of teaching</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Ms.Medha Gourayya</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>5 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>5 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining</td>
# </tr>
# <tr>
# <td>Papers</td>
# <td>
#                                                 3 Papers in National Journals
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Maximixing the efficiency of wireless networks</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>University third rank in M.tech computer engineering</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Ms.Vidya Y</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>6 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>4 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Big Data, Wireless Sensor networks, Data Mining</td>
# </tr>
# <tr>
# <td>Papers</td>
# <td>
#                                                 4 Papers in National Conferences
#                                             </td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Ms.Rashmi M</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td> 2 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>2 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>MANETS, Data Mining, Neural Networks</td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Artificial Intelligence and Stimulus Response System , Implementation of One-to-One Optimization Technique to Improve Data Storage in MANETS</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Shrinivas Biradar</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>4.5 years of teaching</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>1 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Web Mining</td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Fatigue meter, Biospec</td></tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Ms.Chethana H R</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Professor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.E, M.Tech</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>1 Year of teaching, 8.5 years of industry</td>
# </tr>
# <tr>
# <td>Experience in RNSIT</td>
# <td>1 Years</td>
# </tr>
# <tr>
# </tr><tr>
# <td>
#                                                 Areas Of Interest
#                                             </td>
# <td>Data Mining</td>
# </tr>
# <tr>
# <td>Papers</td>
# <td>
#                                                 3 Papers in National Journals
#                                             </td>
# </tr>
# <tr>
# <td>
#                                                 Projects
#                                             </td>
# <td>Maximixing the efficiency of wireless networks</td>
# </tr>
# <tr>
# <td>Other Achievements</td>
# <td>Received Bravo Award at IBM for excellent performance, Completed IBM DB2 certification in 2007, Received BEST PAPER AWARD for presenting my research work on Attribute Based Access for Information Sharing Networks in Cloud at Third National Conference On Wireless Control &amp; Communication Technologies conducted by Department of Telecommunication Engineering, Dr AIT, Bangalore. "
#                                             </td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.R Sundar Krishna</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>System Analyst</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE, MS</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>23 years of teaching</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Deepa S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Programmer</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE,(M.Tech)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>7 years of teaching</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Ravikiran M Devadiga T</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Programmer</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BE,(M.Tech)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>2 years of teaching</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mrs.Mamatha P K</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td> Assistant Instructor</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>Diploma in CS</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>2 years of teaching</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Vinayak P H</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Semi Skilled Lab Assistant</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>BA, A+,N+ (MCA)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>9 years</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Rajesh</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Semi Skilled Lab Assistant</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC, DEC,(BE)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>7 years</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Nagendra T P</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Semi Skilled Lab Assistant</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC, DCH,(BA)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>19 years</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Radhakrishna B S</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Helper</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>B.A., B.L.I.Sc</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>20 years</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Ganapathi</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Helper</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC,(B.Sc(IT))</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>4 years</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Vithal M</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Attender</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>PUC,(BA)</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>4 years</td>
# </tr>
# </tbody>
# </table>
# <table>
# <tbody>
# <tr>
# <td>Name</td>
# <td>Mr.Krishna Murthy</td>
# </tr>
# <tr>
# <td>Designation</td>
# <td>Peon</td>
# </tr>
# <tr>
# <td>Qualification</td>
# <td>SSLC</td>
# </tr>
# <tr>
# <td>Total Experience</td>
# <td>3 years</td>
# </tr>
# </tbody>
# </table>

# %%
find_p_tag=soup.find_all('p')
find_p_tag

i=0
for i in range(len(find_p_tag)):
    if (i>10):
        print(find_p_tag[i].string)
        
type(find_p_tag)
# Out:
#  Dr. G. T. Raju
#  Vice-Principal, Professor and Head of CSE
# Dr.Kavya Naveen
# Professor
#  Dr.Girijamma H A
#  Professor
# Dr.Shashidhara H R
#  Assistant Professor
#  Dr.S Sathish Kumar
# Associate Professor
# Dr.Kiran P
# Associate Professor.
#  Mr.Hemanth S
# Associate Professor
#  Mr.Bhavani Shankar.K
#  Assistant Professor
#  Mr.Anjan Kumar K. N
#  Assistant Professor
#  Mrs.Sudhamani M J
#  Assistant Professor
#  Mrs.Mamatha Jajur
#  Assistant Professor
#  Mrs.Manjula L
#  Assistant Professor
#  Mr.Sanjay P Kalas
#  Assistant Professor
# Mrs.Mahima M Katti
# Assistant Professor
#  Mrs.Swathi G
#  Assistant Professor
#  Mr.Devaraj B. M
#  Assistant Professor
# Mr.Chandrashekar B S
# Assistant Professor
#  Mrs.Sampada K. S
#  Assistant Professor
# Mr.Karanam Sunil Kumar
#  Assistant Professor
#  Mrs.Ramyashree A N
#  Assistant Professor
#  Ms.Reshma Jakabal
#  Assistant Professor
#  Mr.Chethan D S
#  Assistant Professor
#  Ms.Medha Gourayya
#  Assistant Professor
#  Ms.Vidya Y
#  Assistant Professor
#  Ms.Rashmi M
#  Assistant Professor
#  Mr.Shrinivas Biradar
#  Assistant Professor
#  Ms.Chethana H R
#  Assistant Professor
# Non-Teaching Staff
# Mr.R Sundar Krishna
# System Analyst
# Mrs.Deepa S
# Programmer
# Mr.Ravikiran M Devadiga T
# Programmer
# Mrs.Mamatha P K
#  Assistant Instructor
#  Mr.Vinayak P H
# Semi Skilled Lab Assistant
# Mr.Rajesh
# Semi Skilled Lab Assistant
# Mr.Nagendra T P
# Semi Skilled Lab Assistant
# Mr.Radhakrishna B S
# Helper
# Mr.Ganapathi
# Helper
# Mr.Vithal M
# Attender
# Mr.Krishna Murthy
# Peon
# Maintained by Dept of ISE
# bs4.element.ResultSet

# %%
find_tbody_tag=soup.find_all('tbody')
find_tbody_tag
# Out:
# [<tbody>
#  <tr>
#  <td>Name</td>
#  <td>Dr.G T Raju</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Vice-Principal, Professor and Head of CSE</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>BE(CSE), ME(CSE), PhD</td>
#  </tr>
#  <td>Total Experience</td>
#  <td>25+ years of teaching, 1 year of industry, 14+ years of research</td>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>10 Years</td>
#  </tr>
#  <tr>
#  <td>Research and Guidance</td>
#  <td>12 PhDs, 2 Scholars submitted thesis, 5 PhD students being guided</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>
#                                                  Data Mining, Web Mining Image Processing, Prefetching and Caching, Information Retrieval
#                                              </td>
#  </tr>
#  <tr>
#  <td>Projects</td>
#  <td>Guided 86 UG students' projects, 36 PG students' projects, 12 MCA students' projects 4 Research Projects under Grants from AICTE, VTU</td>
#  </tr>
#  <tr>
#  <td>
#                                                  Papers
#                                              </td>
#  <td>Published 65+ papers at reputed indexed International Journals, 45+ papers at reputed Intrrnational Conferences and 6 at National conferences</td>
#  </tr>
#  <tr>
#  <td>No of Books Published</td>
#  <td>5</td>
#  </tr>
#  <tr>
#  <td>FDPs, Conferences, Seminars and Talks</td>
#  <td>35+ FDP conferences organized, 60+ Worshops attended, 36+ National and International conferences attended, 39+ Talks delivered</td>
#  </tr>
#  <tr>
#  <td>Projects Managed</td>
#  <td>86+ Projects for UG students, 48+ Projects for PG students, 15+ Projects for MCA students</td>
#  </tr>
#  <tr>
#  <td>Research Grants</td>
#  <td>12 Lakhs as reseacrh grant from AICTE under MODROB scheme during 1995/96, 9 Lakhs from VTU and AICTE under research grant scheme during 2011/12</td>
#  </tr>
#  <tr>
#  <td>Other Achievements</td>
#  <td>Best Teacher Award and Rajiv Gandhi Gold Medal</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name:</td>
#  <td> Dr.Kavya Naveen</td>
#  </tr>
#  <tr>
#  <td>Email:</td>
#  <td> n.p.kavya@rnsit.ac.in</td>
#  </tr>
#  <tr>
#  <td>Designation:</td>
#  <td>Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification:</td>
#  <td>Ph.D In CSE</td>
#  </tr>
#  <tr>
#  <td>Areas of interest:</td>
#  <td>Big Data Analytics, Data Science, Data Mining &amp;Warehousing</td>
#  </tr>
#  <tr>
#  <td>Projects:</td>
#  <td>
#  <ul>
#  <li>Guided Projects for BE/MCA/Mtech candidates</li>
#  <li>
#                                          Project on Privacy Preservation in Data Mining</li>
#  <li>
#                                          Big data analysis for centimental data representation</li>
#  <li>
#                                          Process mining for server central logs at SET Labs , Infosys Pvt, Ltd, E-city , Bangalore Video Denoising</li>
#  </ul>
#  </td>
#  </tr>
#  <tr>
#  <td>Papers:</td>
#  <td>Published 57 research papers in various Intrenational conferences /Journals which includes IEEE, Springer, Elsivier, ACM, Scopus Indexed with high Impact factor.</td>
#  </tr>
#  <tr>
#  <td>Books written:</td>
#  <td>
#  <ul>
#  <li>1.Dr.N P Kavya, Database Management Systems ,Thakur Publishers ISBN: 978-93-83922-26-0 , First Edition 2015</li>
#  <li>
#                                          2. Dr.N .P Kavya , Database Management Systems, Thakur Publishers, ISBN:978-93-83922-260 ,Second Edition 2017</li>
#  </ul>
#  </td>
#  </tr>
#  <tr>
#  <td>Total Experience:</td>
#  <td>23 Years</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT:</td>
#  <td>15 Years</td>
#  </tr>
#  <tr>
#  <td>Other Achievements:</td>
#  <td>
#  <ul>
#  <li>LIC Committee member for VTU</li>
#  <li>
#                                          BOE/BOS Chairman/member of VTU in CSE/MCA &amp;4 autonomous Institutions</li>
#  <li>
#                                          Board of Advisory council member in various Colleges</li>
#  <li>
#                                          Reviewer /TPC &amp;Advisory Board member for 20 international conference</li>
#  <li>
#
#                                          Bharat Jyoti Award and Certificate of Excellence for remarkable achievements in field of Science and technology , on 29th August 2012 , at National Seminar on Economic Growth and National Integration, By IIFS , New Delhi, India.</li>
#  <li>
#                                          Glory of India gold medal was awarded on 20th August 2012 , at National Seminar on Role of education in modern India, By International Institute of Success Awareness New Delhi, India.</li>
#  <li>
#                                          Best Professor for academic excellence award at RNSIT Bangalore Organized around 30 workshops for students and 10 FDP programs for Faculty of colleges all over Karnataka</li>
#  </ul>
#  </td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Dr.Girijamma H A</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, MTech, Ph.D</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>16 years of teaching, 2 years of industry, 9 years of research</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Dr.Shashidhara H R</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>25 years of teaching, 1 year of research</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>6</td>
#  </tr>
#  <td>
#                                          Areas Of Interest
#                                      </td>
#  <td>
#                                          Data Mining, Web Mining</td>
#  <tr>
#  <td>Projects</td>
#  <td>Published 50 UG projects and 30 PG projects</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Dr.S Sathish Kumar</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Associate Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>25 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>15 Years</td>
#  </tr>
#  <tr>
#  <td>
#                                              Areas Of Interest
#                                          </td>
#  <td>
#                                              Data Mining Bio-informatics Cloud Computing Internet of Things</td>
#  </tr>
#  <tr>
#  <td>Projects</td>
#  <td>Guided 2 projects for KSCST</td>
#  </tr>
#  <tr>
#  <td>
#                                              Papers
#                                          </td>
#  <td>Published 19 Papers in National and International magazines</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Dr.Kiran P</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Associate Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>11 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>14 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>
#                                                  Cryptography, Randomization &amp;Anonymization methods in generalization, Indexing techniques and Design patterns, Data Mining, Database Management Systems
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Papers
#                                              </td>
#  <td>Published 12 Papers in National and International Magazines</td>
#  </tr>
#  <tr>
#  <td>Other Achievements</td>
#  <td>Best Teacher Award in 2005 and 2006 in RNSIT</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Hemanth S</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Associate Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D-Pursuing</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>14 years of teaching, 2 years of industry</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>14 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Data Mining
#                                              </td>
#  </tr>
#  <tr>
#  <td>Projects</td>
#  <td>Semantic analysis using Python NLTK</td>
#  </tr>
#  <tr>
#  <td>
#                                                  Papers
#                                              </td>
#  <td>Published 1 Paper in National Magazines</td>
#  </tr>
#  <tr>
#  <td>Other Achievements</td>
#  <td>Best Teacher Award, Technical training for Placement</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Bhavani Shankar.K</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D-Pursuing</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>13 years of teaching, 5 years of industry</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Anjan Kumar K. N</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D-Pursuing</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>15 years of teaching, 3 years 5 months of industry</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>9 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>
#                                                  Network Security, IOT Protocol Stack, Data Mining
#                                              </td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Sudhamani M J</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D-Pursuing</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>13 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>13 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Image Processing and pattern Recognitions, Computer Architecture
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Papers
#                                              </td>
#  <td>Publised 7 Papers in National and International Magazines</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Mamatha Jajur</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D-Pursuing</td>
#  </tr>
#  <!-- <tr>
#                        <td>Total Experience</td>
#                        <td>10 Years</td>
#                      </tr>
#                      <tr>
#                        <td>Experience in RNSIT</td>
#                        <td>10 Years</td>
#                      </tr> -->
#  <!-- <tr>
#                        <tr>
#                          <td>
#                            Areas Of Interest
#                          </td>
#                          <td>Artificial Intelligence, Neural Networks, Embedded Computing Systems
#                          </td>
#                        </tr>
#                        <tr>
#                          <td>
#                            Projects
#                          </td>
#                          <td>Intranet Chatting, RTOS Sytem Application,Embedded Computing Systems</td>
#                        </tr> -->
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Manjula L</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech, Ph.D-Pursuing</td>
#  </tr>
#  <!-- <tr>
#                        <td>Total Experience</td>
#                        <td>10 Years</td>
#                      </tr>
#                      <tr>
#                        <td>Experience in RNSIT</td>
#                        <td>10 Years</td>
#                      </tr> -->
#  <!-- <tr>
#                        <tr>
#                          <td>
#                            Areas Of Interest
#                          </td>
#                          <td>Artificial Intelligence, Neural Networks, Embedded Computing Systems
#                          </td>
#                        </tr>
#                        <tr>
#                          <td>
#                            Projects
#                          </td>
#                          <td>Intranet Chatting, RTOS Sytem Application,Embedded Computing Systems</td>
#                        </tr> -->
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Sanjay P Kalas</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>10 years of teaching</td>
#  </tr><tr>
#  <td>Experience in RNSIT</td>
#  <td>10 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                      Areas Of Interest
#                                                  </td>
#  <td>Data Mining,Wireless Sensor Networks,IOT
#                                                  </td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Mahima M Katti</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>11.75 years of teaching</td>
#  </tr><tr>
#  <td>Experience in RNSIT</td>
#  <td>3.25 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                      Areas Of Interest
#                                                  </td>
#  <td>Network Security, Wireless Networks, Applications of Microprocessors,
#                                                  </td>
#  </tr>
#  <tr>
#  <td>
#                                                      Papers
#                                                  </td>
#  <td>2 papers (Where?)</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Swathi G</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.Tech, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>10 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>10 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Software Testing
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>An Enhanced Healthcare systems</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Devaraj B. M</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.E, (Ph.D)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>12 years of teaching,2 years of industry</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>9 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Network Security, Data Mining
#                                              </td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Chandrashekar B S</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>7 years of teaching, 4 years of industry</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Sampada K. S</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>14 years of teaching, 3.5 years of industry</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>10 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Text Mining, Big data, Networks</td>
#  </tr>
#  <tr>
#  <td>Papers</td>
#  <td>
#                                                  5 Papers in International Journals
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>1.iAgni Management System for Karnataka State Fire &amp;Emergency Services(KSFES) 2. ROSAT Student management and assessment system.</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Karanam Sunil Kumar</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>10 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>10 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Video tracking, Data Structures</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Ramyashree A N</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.Tech, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>12 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>11 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Data Mining, Computer Networks</td>
#  </tr>
#  <tr>
#  <td>Papers</td>
#  <td>
#                                                  2 Papers in International Journals and 2 in National Journals
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>Performance analysis of iSCSI in a SAN using software based target and initiator e- basket Customer management
#                                              </td>
#  </tr>
#  <tr>
#  <td>Other Achievements</td>
#  <td>Won Best Paper award at national conference-SJBIT 2010 STATE AWARD winner for essay writing on Global warming and it's consequences in 1998-1999 Member of Technical Training Team at RNSIT.</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Ms.Reshma Jakabal</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>8 years</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>5 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Data Mining, Big Data, Networking</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Chethan D S</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>6 years of teaching</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Ms.Medha Gourayya</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>5 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>5 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Data Mining</td>
#  </tr>
#  <tr>
#  <td>Papers</td>
#  <td>
#                                                  3 Papers in National Journals
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>Maximixing the efficiency of wireless networks</td>
#  </tr>
#  <tr>
#  <td>Other Achievements</td>
#  <td>University third rank in M.tech computer engineering</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Ms.Vidya Y</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>6 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>4 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Big Data, Wireless Sensor networks, Data Mining</td>
#  </tr>
#  <tr>
#  <td>Papers</td>
#  <td>
#                                                  4 Papers in National Conferences
#                                              </td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Ms.Rashmi M</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td> 2 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>2 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>MANETS, Data Mining, Neural Networks</td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>Artificial Intelligence and Stimulus Response System , Implementation of One-to-One Optimization Technique to Improve Data Storage in MANETS</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Shrinivas Biradar</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>4.5 years of teaching</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>1 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Web Mining</td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>Fatigue meter, Biospec</td></tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Ms.Chethana H R</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Professor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.E, M.Tech</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>1 Year of teaching, 8.5 years of industry</td>
#  </tr>
#  <tr>
#  <td>Experience in RNSIT</td>
#  <td>1 Years</td>
#  </tr>
#  <tr>
#  </tr><tr>
#  <td>
#                                                  Areas Of Interest
#                                              </td>
#  <td>Data Mining</td>
#  </tr>
#  <tr>
#  <td>Papers</td>
#  <td>
#                                                  3 Papers in National Journals
#                                              </td>
#  </tr>
#  <tr>
#  <td>
#                                                  Projects
#                                              </td>
#  <td>Maximixing the efficiency of wireless networks</td>
#  </tr>
#  <tr>
#  <td>Other Achievements</td>
#  <td>Received Bravo Award at IBM for excellent performance, Completed IBM DB2 certification in 2007, Received BEST PAPER AWARD for presenting my research work on Attribute Based Access for Information Sharing Networks in Cloud at Third National Conference On Wireless Control &amp; Communication Technologies conducted by Department of Telecommunication Engineering, Dr AIT, Bangalore. "
#                                              </td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.R Sundar Krishna</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>System Analyst</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>BE, MS</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>23 years of teaching</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Deepa S</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Programmer</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>BE,(M.Tech)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>7 years of teaching</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Ravikiran M Devadiga T</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Programmer</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>BE,(M.Tech)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>2 years of teaching</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mrs.Mamatha P K</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td> Assistant Instructor</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>Diploma in CS</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>2 years of teaching</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Vinayak P H</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Semi Skilled Lab Assistant</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>BA, A+,N+ (MCA)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>9 years</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Rajesh</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Semi Skilled Lab Assistant</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>PUC, DEC,(BE)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>7 years</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Nagendra T P</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Semi Skilled Lab Assistant</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>PUC, DCH,(BA)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>19 years</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Radhakrishna B S</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Helper</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>B.A., B.L.I.Sc</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>20 years</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Ganapathi</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Helper</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>PUC,(B.Sc(IT))</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>4 years</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Vithal M</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Attender</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>PUC,(BA)</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>4 years</td>
#  </tr>
#  </tbody>, <tbody>
#  <tr>
#  <td>Name</td>
#  <td>Mr.Krishna Murthy</td>
#  </tr>
#  <tr>
#  <td>Designation</td>
#  <td>Peon</td>
#  </tr>
#  <tr>
#  <td>Qualification</td>
#  <td>SSLC</td>
#  </tr>
#  <tr>
#  <td>Total Experience</td>
#  <td>3 years</td>
#  </tr>
#  </tbody>]

# %%
#Name,Designation,Qualification,Experience_in_rnsit,Research_and_guidance,area_of_interest,
#projects,papers,No_of_books_published,

for row in soup.find_all('tbody'):
    for tr in row.find_all('tr'):
        tf=find_all('td')
        for td in tr.find_all('td'):
            for i in range(len(td)):
                print(td[].string)
    print()            
type(td)
# Out:
#   File "<ipython-input-6-470bdc76a002>", line 9
#     print(td[].string)
#              ^
# SyntaxError: invalid syntax

# %%
print(zip(headers,data))
for item1, item2 in zip(headers, data):
    print(item1, "...", item2)

# %%
for row in soup.find_all('tbody'):
    print(row.)

# %%
#Name,Email,Designation,Qualification,Experience_in_rnsit,Research_and_guidance,area_of_interest,
#projects,papers,No_of_books_published,FDPs, Conferences, Seminars and Talks,project_managed,
#Research_grants,other_achievements,Books_written,Total_experience

for row in soup.find_all('tbody'):
    for tr in row.find_all('tr'):
        tf=tr.find_all('td')
        for i in range(len(tf)):
            if i==0:
                print(tf[i].string)
    print()            
type(td)

# %%
#Name,Email,Designation,Qualification,Experience_in_rnsit,Research_and_guidance,area_of_interest,
#projects,papers,No_of_books_published,FDPs, Conferences, Seminars and Talks,project_managed,
#Research_grants,other_achievements,Books_written,Total_experience

for row in soup.find_all('tbody'):
    for tr in row.find_all('tr'):
        tf=tr.find_all('td')
        for i in range(len(tf)):
            if tf[0]=="Designation":
                print(tf[1].string)
    print()            
type(td)

# %%
#Name,Email,Designation,Qualification,Experience_in_rnsit,Research_and_guidance,area_of_interest,
#projects,papers,No_of_books_published,FDPs, Conferences, Seminars and Talks,project_managed,
#Research_grants,other_achievements,Books_written,Total_experience
arr=[]
for row in soup.find_all('tbody'):
    for tr in row.find_all('tr'):
        tf=tr.find_all('td')
        for i in range(len(tf)):
            if (tf[i].string=='Name'):
                (arr.append(tf[1].string)
            else:
                 arr.append("0")

# %%
#Name,Email,Designation,Qualification,Experience_in_rnsit,Research_and_guidance,area_of_interest,
#projects,papers,No_of_books_published,FDPs, Conferences, Seminars and Talks,project_managed,
#Research_grants,other_achievements,Books_written,Total_experience

Name=[]
Designation=[]
Qualification=[]
Total_Experience=[]
Experience_in_RNSIT=[]
Areas_Of_Interest=[]
project=[]

for row in soup.find_all('tbody'):
    for tr in row.find_all('tr'):
        tf=tr.find_all('td')
        for i in range(len(tf)):
            if (tf[i].string=='Name'):
                print(Name.append(tf[1].string))
            #else:
            #    print(arr.append(tf[1].string))
            if(tf[i].string=='Designation'):
                print(Designation.append(tf[1].string))
                
            if(tf[i].string=='Qualification'):
                print(Qualification.append(tf[1].string))
                
            
print(Name)
print(Designation)
print(Qualification)
print(Total_Experience)
print(len(Name))
print(len(Designation))
print(len(Qualification))
print(len(Total_Experience))
# Out:
#   File "<ipython-input-210-b398e4aad393>", line 32
#     print(Name)
#         ^
# SyntaxError: invalid syntax

# %%
#Name,Email,Designation,Qualification,Experience_in_rnsit,Research_and_guidance,area_of_interest,
#projects,papers,No_of_books_published,FDPs, Conferences, Seminars and Talks,project_managed,
#Research_grants,other_achievements,Books_written,Total_experience

Name=[]
Designation=[]
Qualification=[]
Total_Experience=[]
Experience_in_RNSIT=[]
Areas_Of_Interest=[]
project=[]

for row in soup.find_all('tbody'):
    for tr in row.find_all('tr'):
        tf=tr.find_all('td')
        for i in range(len(tf)):
            if (tf[i].string=='Name'):
                print(Name.append(tf[1].string))
            #else:
            #    print(arr.append(tf[1].string))
            elif(tf[i].string=='Designation'):
                print(Designation.append(tf[1].string))
                
            elif(tf[i].string=='Qualification'):
                print(Qualification.append(tf[1].string))
            
            

print(Name)
print(Designation)
print(Qualification)
print(len(Name))
print(len(Designation))
print(len(Qualification))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ['Dr.G T Raju', 'Dr.Girijamma H A', 'Dr.Shashidhara H R', 'Dr.S Sathish Kumar', 'Dr.Kiran P', 'Mr.Hemanth S', 'Mr.Bhavani Shankar.K', 'Mr.Anjan Kumar K. N', 'Mrs.Sudhamani M J', 'Mrs.Mamatha Jajur', 'Mrs.Manjula L', 'Mr.Sanjay P Kalas', 'Mrs.Mahima M Katti', 'Mrs.Swathi G', 'Mr.Devaraj B. M', 'Mr.Chandrashekar B S', 'Mrs.Sampada K. S', 'Mr.Karanam Sunil Kumar', 'Mrs.Ramyashree A N', 'Ms.Reshma Jakabal', 'Mr.Chethan D S', 'Ms.Medha Gourayya', 'Ms.Vidya Y', 'Ms.Rashmi M', 'Mr.Shrinivas Biradar', 'Ms.Chethana H R', 'Mr.R Sundar Krishna', 'Mrs.Deepa S', 'Mr.Ravikiran M Devadiga T', 'Mrs.Mamatha P K', 'Mr.Vinayak P H', 'Mr.Rajesh', 'Mr.Nagendra T P', 'Mr.Radhakrishna B S', 'Mr.Ganapathi', 'Mr.Vithal M', 'Mr.Krishna Murthy']
# ['Vice-Principal, Professor and Head of CSE', 'Professor', ' Assistant Professor', 'Associate Professor', 'Associate Professor', 'Associate Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', ' Assistant Professor', 'System Analyst', 'Programmer', 'Programmer', ' Assistant Instructor', 'Semi Skilled Lab Assistant', 'Semi Skilled Lab Assistant', 'Semi Skilled Lab Assistant', 'Helper', 'Helper', 'Attender', 'Peon']
# ['BE(CSE), ME(CSE), PhD', 'B.E, MTech, Ph.D', 'B.E, M.Tech, Ph.D', 'B.E, M.Tech, Ph.D', 'B.E, M.Tech, Ph.D', 'B.E, M.Tech, Ph.D-Pursuing', 'B.E, M.Tech, Ph.D-Pursuing', 'B.E, M.Tech, Ph.D-Pursuing', 'B.E, M.Tech, Ph.D-Pursuing', 'B.E, M.Tech, Ph.D-Pursuing', 'B.E, M.Tech, Ph.D-Pursuing', 'B.E, M.Tech', 'M.Tech', 'B.Tech, M.Tech', 'B.E, M.E, (Ph.D)', 'B.E, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'B.Tech, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'B.E, M.Tech', 'BE, MS', 'BE,(M.Tech)', 'BE,(M.Tech)', 'Diploma in CS', 'BA, A+,N+ (MCA)', 'PUC, DEC,(BE)', 'PUC, DCH,(BA)', 'B.A., B.L.I.Sc', 'PUC,(B.Sc(IT))', 'PUC,(BA)', 'SSLC']
# 37
# 37
# 37

# %%
import pandas as pd

# %%
name=pd.DataFrame(Name)
designation=pd.DataFrame(Designation)
qualification=pd.DataFrame(Qualification)

# %%
data=pd.concat([name,designation,qualification],axis=1)

# %%
help(pd.concat)
# Out:
# Help on function concat in module pandas.core.reshape.concat:
#
# concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=None, copy=True)
#     Concatenate pandas objects along a particular axis with optional set logic
#     along the other axes.
#
#     Can also add a layer of hierarchical indexing on the concatenation axis,
#     which may be useful if the labels are the same (or overlapping) on
#     the passed axis number.
#
#     Parameters
#     ----------
#     objs : a sequence or mapping of Series, DataFrame, or Panel objects
#         If a dict is passed, the sorted keys will be used as the `keys`
#         argument, unless it is passed, in which case the values will be
#         selected (see below). Any None objects will be dropped silently unless
#         they are all None in which case a ValueError will be raised
#     axis : {0/'index', 1/'columns'}, default 0
#         The axis to concatenate along
#     join : {'inner', 'outer'}, default 'outer'
#         How to handle indexes on other axis(es)
#     join_axes : list of Index objects
#         Specific indexes to use for the other n - 1 axes instead of performing
#         inner/outer set logic
#     ignore_index : boolean, default False
#         If True, do not use the index values along the concatenation axis. The
#         resulting axis will be labeled 0, ..., n - 1. This is useful if you are
#         concatenating objects where the concatenation axis does not have
#         meaningful indexing information. Note the index values on the other
#         axes are still respected in the join.
#     keys : sequence, default None
#         If multiple levels passed, should contain tuples. Construct
#         hierarchical index using the passed keys as the outermost level
#     levels : list of sequences, default None
#         Specific levels (unique values) to use for constructing a
#         MultiIndex. Otherwise they will be inferred from the keys
#     names : list, default None
#         Names for the levels in the resulting hierarchical index
#     verify_integrity : boolean, default False
#         Check whether the new concatenated axis contains duplicates. This can
#         be very expensive relative to the actual data concatenation
#     sort : boolean, default None
#         Sort non-concatenation axis if it is not already aligned when `join`
#         is 'outer'. The current default of sorting is deprecated and will
#         change to not-sorting in a future version of pandas.
#
#         Explicitly pass ``sort=True`` to silence the warning and sort.
#         Explicitly pass ``sort=False`` to silence the warning and not sort.
#
#         This has no effect when ``join='inner'``, which already preserves
#         the order of the non-concatenation axis.
#
#         .. versionadded:: 0.23.0
#
#     copy : boolean, default True
#         If False, do not copy data unnecessarily
#
#     Returns
#     -------
#     concatenated : object, type of objs
#         When concatenating all ``Series`` along the index (axis=0), a
#         ``Series`` is returned. When ``objs`` contains at least one
#         ``DataFrame``, a ``DataFrame`` is returned. When concatenating along
#         the columns (axis=1), a ``DataFrame`` is returned.
#
#     Notes
#     -----
#     The keys, levels, and names arguments are all optional.
#
#     A walkthrough of how this method fits in with other tools for combining
#     pandas objects can be found `here
#     <http://pandas.pydata.org/pandas-docs/stable/merging.html>`__.
#
#     See Also
#     --------
#     Series.append
#     DataFrame.append
#     DataFrame.join
#     DataFrame.merge
#
#     Examples
#     --------
#     Combine two ``Series``.
#
#     >>> s1 = pd.Series(['a', 'b'])
#     >>> s2 = pd.Series(['c', 'd'])
#     >>> pd.concat([s1, s2])
#     0    a
#     1    b
#     0    c
#     1    d
#     dtype: object
#
#     Clear the existing index and reset it in the result
#     by setting the ``ignore_index`` option to ``True``.
#
#     >>> pd.concat([s1, s2], ignore_index=True)
#     0    a
#     1    b
#     2    c
#     3    d
#     dtype: object
#
#     Add a hierarchical index at the outermost level of
#     the data with the ``keys`` option.
#
#     >>> pd.concat([s1, s2], keys=['s1', 's2',])
#     s1  0    a
#         1    b
#     s2  0    c
#         1    d
#     dtype: object
#
#     Label the index keys you create with the ``names`` option.
#
#     >>> pd.concat([s1, s2], keys=['s1', 's2'],
#     ...           names=['Series name', 'Row ID'])
#     Series name  Row ID
#     s1           0         a
#                  1         b
#     s2           0         c
#                  1         d
#     dtype: object
#
#     Combine two ``DataFrame`` objects with identical columns.
#
#     >>> df1 = pd.DataFrame([['a', 1], ['b', 2]],
#     ...                    columns=['letter', 'number'])
#     >>> df1
#       letter  number
#     0      a       1
#     1      b       2
#     >>> df2 = pd.DataFrame([['c', 3], ['d', 4]],
#     ...                    columns=['letter', 'number'])
#     >>> df2
#       letter  number
#     0      c       3
#     1      d       4
#     >>> pd.concat([df1, df2])
#       letter  number
#     0      a       1
#     1      b       2
#     0      c       3
#     1      d       4
#
#     Combine ``DataFrame`` objects with overlapping columns
#     and return everything. Columns outside the intersection will
#     be filled with ``NaN`` values.
#
#     >>> df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
#     ...                    columns=['letter', 'number', 'animal'])
#     >>> df3
#       letter  number animal
#     0      c       3    cat
#     1      d       4    dog
#     >>> pd.concat([df1, df3])
#       animal letter  number
#     0    NaN      a       1
#     1    NaN      b       2
#     0    cat      c       3
#     1    dog      d       4
#
#     Combine ``DataFrame`` objects with overlapping columns
#     and return only those that are shared by passing ``inner`` to
#     the ``join`` keyword argument.
#
#     >>> pd.concat([df1, df3], join="inner")
#       letter  number
#     0      a       1
#     1      b       2
#     0      c       3
#     1      d       4
#
#     Combine ``DataFrame`` objects horizontally along the x axis by
#     passing in ``axis=1``.
#
#     >>> df4 = pd.DataFrame([['bird', 'polly'], ['monkey', 'george']],
#     ...                    columns=['animal', 'name'])
#     >>> pd.concat([df1, df4], axis=1)
#       letter  number  animal    name
#     0      a       1    bird   polly
#     1      b       2  monkey  george
#
#     Prevent the result from including duplicate index values with the
#     ``verify_integrity`` option.
#
#     >>> df5 = pd.DataFrame([1], index=['a'])
#     >>> df5
#        0
#     a  1
#     >>> df6 = pd.DataFrame([2], index=['a'])
#     >>> df6
#        0
#     a  2
#     >>> pd.concat([df5, df6], verify_integrity=True)
#     Traceback (most recent call last):
#         ...
#     ValueError: Indexes have overlapping values: ['a']

# %%
data.csv=data.to_csv("/home/shashanksoni092/DataScienceWorkspace/WebScrapping/RNSIT/rns.csv")
#/home/DataScienceWorkspace/WebScrapping/RNSIT/
help(data.to_csv)
# Out:
# Help on method to_csv in module pandas.core.frame:
#
# to_csv(path_or_buf=None, sep=',', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, mode='w', encoding=None, compression=None, quoting=None, quotechar='"', line_terminator='\n', chunksize=None, tupleize_cols=None, date_format=None, doublequote=True, escapechar=None, decimal='.') method of pandas.core.frame.DataFrame instance
#     Write DataFrame to a comma-separated values (csv) file
#
#     Parameters
#     ----------
#     path_or_buf : string or file handle, default None
#         File path or object, if None is provided the result is returned as
#         a string.
#     sep : character, default ','
#         Field delimiter for the output file.
#     na_rep : string, default ''
#         Missing data representation
#     float_format : string, default None
#         Format string for floating point numbers
#     columns : sequence, optional
#         Columns to write
#     header : boolean or list of string, default True
#         Write out the column names. If a list of strings is given it is
#         assumed to be aliases for the column names
#     index : boolean, default True
#         Write row names (index)
#     index_label : string or sequence, or False, default None
#         Column label for index column(s) if desired. If None is given, and
#         `header` and `index` are True, then the index names are used. A
#         sequence should be given if the DataFrame uses MultiIndex.  If
#         False do not print fields for index names. Use index_label=False
#         for easier importing in R
#     mode : str
#         Python write mode, default 'w'
#     encoding : string, optional
#         A string representing the encoding to use in the output file,
#         defaults to 'ascii' on Python 2 and 'utf-8' on Python 3.
#     compression : string, optional
#         A string representing the compression to use in the output file.
#         Allowed values are 'gzip', 'bz2', 'zip', 'xz'. This input is only
#         used when the first argument is a filename.
#     line_terminator : string, default ``'\n'``
#         The newline character or character sequence to use in the output
#         file
#     quoting : optional constant from csv module
#         defaults to csv.QUOTE_MINIMAL. If you have set a `float_format`
#         then floats are converted to strings and thus csv.QUOTE_NONNUMERIC
#         will treat them as non-numeric
#     quotechar : string (length 1), default '\"'
#         character used to quote fields
#     doublequote : boolean, default True
#         Control quoting of `quotechar` inside a field
#     escapechar : string (length 1), default None
#         character used to escape `sep` and `quotechar` when appropriate
#     chunksize : int or None
#         rows to write at a time
#     tupleize_cols : boolean, default False
#         .. deprecated:: 0.21.0
#            This argument will be removed and will always write each row
#            of the multi-index as a separate row in the CSV file.
#
#         Write MultiIndex columns as a list of tuples (if True) or in
#         the new, expanded format, where each MultiIndex column is a row
#         in the CSV (if False).
#     date_format : string, default None
#         Format string for datetime objects
#     decimal: string, default '.'
#         Character recognized as decimal separator. E.g. use ',' for
#         European data

# %%
data
# Out:
#                          Name                                       Name  \
# 0                 Dr.G T Raju  Vice-Principal, Professor and Head of CSE
# 1            Dr.Girijamma H A                                  Professor
# 2          Dr.Shashidhara H R                        Assistant Professor
# 3          Dr.S Sathish Kumar                        Associate Professor
# 4                  Dr.Kiran P                        Associate Professor
# 5                Mr.Hemanth S                        Associate Professor
# 6        Mr.Bhavani Shankar.K                        Assistant Professor
# 7         Mr.Anjan Kumar K. N                        Assistant Professor
# 8           Mrs.Sudhamani M J                        Assistant Professor
# 9           Mrs.Mamatha Jajur                        Assistant Professor
# 10              Mrs.Manjula L                        Assistant Professor
# 11          Mr.Sanjay P Kalas                        Assistant Professor
# 12         Mrs.Mahima M Katti                        Assistant Professor
# 13               Mrs.Swathi G                        Assistant Professor
# 14            Mr.Devaraj B. M                        Assistant Professor
# 15       Mr.Chandrashekar B S                        Assistant Professor
# 16           Mrs.Sampada K. S                        Assistant Professor
# 17     Mr.Karanam Sunil Kumar                        Assistant Professor
# 18         Mrs.Ramyashree A N                        Assistant Professor
# 19          Ms.Reshma Jakabal                        Assistant Professor
# 20             Mr.Chethan D S                        Assistant Professor
# 21          Ms.Medha Gourayya                        Assistant Professor
# 22                 Ms.Vidya Y                        Assistant Professor
# 23                Ms.Rashmi M                        Assistant Professor
# 24       Mr.Shrinivas Biradar                        Assistant Professor
# 25            Ms.Chethana H R                        Assistant Professor
# 26        Mr.R Sundar Krishna                             System Analyst
# 27                Mrs.Deepa S                                 Programmer
# 28  Mr.Ravikiran M Devadiga T                                 Programmer
# 29            Mrs.Mamatha P K                       Assistant Instructor
# 30             Mr.Vinayak P H                 Semi Skilled Lab Assistant
# 31                  Mr.Rajesh                 Semi Skilled Lab Assistant
# 32            Mr.Nagendra T P                 Semi Skilled Lab Assistant
# 33        Mr.Radhakrishna B S                                     Helper
# 34               Mr.Ganapathi                                     Helper
# 35                Mr.Vithal M                                   Attender
# 36          Mr.Krishna Murthy                                       Peon
#
#                           Name
# 0        BE(CSE), ME(CSE), PhD
# 1             B.E, MTech, Ph.D
# 2            B.E, M.Tech, Ph.D
# 3            B.E, M.Tech, Ph.D
# 4            B.E, M.Tech, Ph.D
# 5   B.E, M.Tech, Ph.D-Pursuing
# 6   B.E, M.Tech, Ph.D-Pursuing
# 7   B.E, M.Tech, Ph.D-Pursuing
# 8   B.E, M.Tech, Ph.D-Pursuing
# 9   B.E, M.Tech, Ph.D-Pursuing
# 10  B.E, M.Tech, Ph.D-Pursuing
# 11                 B.E, M.Tech
# 12                      M.Tech
# 13              B.Tech, M.Tech
# 14            B.E, M.E, (Ph.D)
# 15                 B.E, M.Tech
# 16                 B.E, M.Tech
# 17                 B.E, M.Tech
# 18              B.Tech, M.Tech
# 19                 B.E, M.Tech
# 20                 B.E, M.Tech
# 21                 B.E, M.Tech
# 22                 B.E, M.Tech
# 23                 B.E, M.Tech
# 24                 B.E, M.Tech
# 25                 B.E, M.Tech
# 26                      BE, MS
# 27                 BE,(M.Tech)
# 28                 BE,(M.Tech)
# 29               Diploma in CS
# 30             BA, A+,N+ (MCA)
# 31               PUC, DEC,(BE)
# 32               PUC, DCH,(BA)
# 33              B.A., B.L.I.Sc
# 34              PUC,(B.Sc(IT))
# 35                    PUC,(BA)
# 36                        SSLC

# %%
help(data.rename)
# Out:
# Help on method rename in module pandas.core.frame:
#
# rename(mapper=None, index=None, columns=None, axis=None, copy=True, inplace=False, level=None) method of pandas.core.frame.DataFrame instance
#     Alter axes labels.
#
#     Function / dict values must be unique (1-to-1). Labels not contained in
#     a dict / Series will be left as-is. Extra labels listed don't throw an
#     error.
#
#     See the :ref:`user guide <basics.rename>` for more.
#
#     Parameters
#     ----------
#     mapper, index, columns : dict-like or function, optional
#         dict-like or functions transformations to apply to
#         that axis' values. Use either ``mapper`` and ``axis`` to
#         specify the axis to target with ``mapper``, or ``index`` and
#         ``columns``.
#     axis : int or str, optional
#         Axis to target with ``mapper``. Can be either the axis name
#         ('index', 'columns') or number (0, 1). The default is 'index'.
#     copy : boolean, default True
#         Also copy underlying data
#     inplace : boolean, default False
#         Whether to return a new %(klass)s. If True then value of copy is
#         ignored.
#     level : int or level name, default None
#         In case of a MultiIndex, only rename labels in the specified
#         level.
#
#     Returns
#     -------
#     renamed : DataFrame
#
#     See Also
#     --------
#     pandas.DataFrame.rename_axis
#
#     Examples
#     --------
#
#     ``DataFrame.rename`` supports two calling conventions
#
#     * ``(index=index_mapper, columns=columns_mapper, ...)``
#     * ``(mapper, axis={'index', 'columns'}, ...)``
#
#     We *highly* recommend using keyword arguments to clarify your
#     intent.
#
#     >>> df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
#     >>> df.rename(index=str, columns={"A": "a", "B": "c"})
#        a  c
#     0  1  4
#     1  2  5
#     2  3  6
#
#     >>> df.rename(index=str, columns={"A": "a", "C": "c"})
#        a  B
#     0  1  4
#     1  2  5
#     2  3  6
#
#     Using axis-style parameters
#
#     >>> df.rename(str.lower, axis='columns')
#        a  b
#     0  1  4
#     1  2  5
#     2  3  6
#
#     >>> df.rename({1: 2, 2: 4}, axis='index')
#        A  B
#     0  1  4
#     2  2  5
#     4  3  6

# %%
data.columns[0]
# Out:
# 'Name'
